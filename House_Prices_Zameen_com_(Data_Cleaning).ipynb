# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshad-Aziz/technical-training/blob/main/House_Prices_Zameen_com_(Data_Cleaning).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing important libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('zameen-updated.csv')
data.head()
# Out:
#    property_id  location_id  \
# 0       237062         3325
# 1       346905         3236
# 2       386513          764
# 3       656161          340
# 4       841645         3226
#
#                                             page_url property_type     price  \
# 0  https://www.zameen.com/Property/g_10_g_10_2_gr...          Flat  10000000
# 1  https://www.zameen.com/Property/e_11_2_service...          Flat   6900000
# 2  https://www.zameen.com/Property/islamabad_g_15...         House  16500000
# 3  https://www.zameen.com/Property/islamabad_bani...         House  43500000
# 4  https://www.zameen.com/Property/dha_valley_dha...         House   7000000
#
#       location       city      province_name   latitude  longitude  baths  \
# 0         G-10  Islamabad  Islamabad Capital  33.679890  73.012640      2
# 1         E-11  Islamabad  Islamabad Capital  33.700993  72.971492      3
# 2         G-15  Islamabad  Islamabad Capital  33.631486  72.926559      6
# 3    Bani Gala  Islamabad  Islamabad Capital  33.707573  73.151199      4
# 4  DHA Defence  Islamabad  Islamabad Capital  33.492591  73.301339      3
#
#         area   purpose  bedrooms  date_added         agency  \
# 0    4 Marla  For Sale         2  02-04-2019            NaN
# 1  5.6 Marla  For Sale         3  05-04-2019            NaN
# 2    8 Marla  For Sale         5  07-17-2019            NaN
# 3    2 Kanal  For Sale         4  04-05-2019            NaN
# 4    8 Marla  For Sale         3  07-10-2019  Easy Property
#
#                                           agent Area Type  Area Size  \
# 0                                           NaN     Marla        4.0
# 1                                           NaN     Marla        5.6
# 2                                           NaN     Marla        8.0
# 3                                           NaN     Kanal        2.0
# 4  Muhammad Junaid Ceo Muhammad Shahid Director     Marla        8.0
#
#   Area Category
# 0     0-5 Marla
# 1    5-10 Marla
# 2    5-10 Marla
# 3     1-5 Kanal
# 4    5-10 Marla

# %%
data.describe()
# Out:
#         property_id    location_id         price       latitude  \
# count  1.224360e+05  122436.000000  1.224360e+05  122436.000000
# mean   1.498675e+07    4389.392556  1.887524e+07      29.835986
# std    2.368414e+06    3754.984753  3.753612e+07       3.807063
# min    8.657500e+04       1.000000  0.000000e+00      11.052446
# 25%    1.405870e+07    1080.000000  3.000000e+05      24.939171
# 50%    1.587265e+07    3310.000000  9.000000e+06      31.458979
# 75%    1.678996e+07    7217.000000  2.000000e+07      33.555066
# max    1.706622e+07   14104.000000  2.000000e+09      73.184088
#
#            longitude          baths       bedrooms      Area Size
# count  122436.000000  122436.000000  122436.000000  122436.000000
# mean       71.236287       3.037040       3.269275       5.865722
# std         3.146212       2.240706       1.958243       4.727997
# min        25.906027       0.000000       0.000000       0.000000
# 25%        67.129080       2.000000       2.000000       3.000000
# 50%        73.056493       3.000000       3.000000       5.000000
# 75%        74.140653       5.000000       5.000000       8.000000
# max        80.161430      13.000000      28.000000     600.000000

# %%
data.head(2)
# Out:
#    property_id  location_id  \
# 0       237062         3325
# 1       346905         3236
#
#                                             page_url property_type     price  \
# 0  https://www.zameen.com/Property/g_10_g_10_2_gr...          Flat  10000000
# 1  https://www.zameen.com/Property/e_11_2_service...          Flat   6900000
#
#   location       city      province_name   latitude  longitude  baths  \
# 0     G-10  Islamabad  Islamabad Capital  33.679890  73.012640      2
# 1     E-11  Islamabad  Islamabad Capital  33.700993  72.971492      3
#
#         area   purpose  bedrooms  date_added agency agent Area Type  \
# 0    4 Marla  For Sale         2  02-04-2019    NaN   NaN     Marla
# 1  5.6 Marla  For Sale         3  05-04-2019    NaN   NaN     Marla
#
#    Area Size Area Category
# 0        4.0     0-5 Marla
# 1        5.6    5-10 Marla

# %%
data=data.drop(['property_id','location_id','page_url','area','Area Category'],axis=1)
data.head()
# Out:
#   property_type     price     location       city      province_name  \
# 0          Flat  10000000         G-10  Islamabad  Islamabad Capital
# 1          Flat   6900000         E-11  Islamabad  Islamabad Capital
# 2         House  16500000         G-15  Islamabad  Islamabad Capital
# 3         House  43500000    Bani Gala  Islamabad  Islamabad Capital
# 4         House   7000000  DHA Defence  Islamabad  Islamabad Capital
#
#     latitude  longitude  baths   purpose  bedrooms  date_added         agency  \
# 0  33.679890  73.012640      2  For Sale         2  02-04-2019            NaN
# 1  33.700993  72.971492      3  For Sale         3  05-04-2019            NaN
# 2  33.631486  72.926559      6  For Sale         5  07-17-2019            NaN
# 3  33.707573  73.151199      4  For Sale         4  04-05-2019            NaN
# 4  33.492591  73.301339      3  For Sale         3  07-10-2019  Easy Property
#
#                                           agent Area Type  Area Size
# 0                                           NaN     Marla        4.0
# 1                                           NaN     Marla        5.6
# 2                                           NaN     Marla        8.0
# 3                                           NaN     Kanal        2.0
# 4  Muhammad Junaid Ceo Muhammad Shahid Director     Marla        8.0

# %%
data.isnull().sum()
# Out:
# property_type        0
# price                0
# location             0
# city                 0
# province_name        0
# latitude             0
# longitude            0
# baths                0
# purpose              0
# bedrooms             0
# date_added           0
# agency           40896
# agent            40896
# Area Type            0
# Area Size            0
# dtype: int64

# %%
total_values=data.index.stop
null_values=data['agency'].isnull().sum()

percentage=null_values/total_values
percentage
# Out:
# 0.33401940605704206

# %%
agency_uniques=data['agency'].unique()[0:-1]
list(agency_uniques)
# Out:
# [nan,
#  'Easy Property',
#  'Ettemad Enterprises',
#  'Crown Associate',
#  'Al Sahar Estate',
#  'Infinity Properties',
#  'Paris Real Estate & Builders',
#  'Property Syendicate',
#  'Zorje Pvt Ltd',
#  'Nexus Estate Services',
#  'Real Biz International',
#  'Khan Estate',
#  'Shahum Estate 2',
#  'MATZ Services',
#  'Sukhera Estate & Builders',
#  'Hamza Real Estate',
#  'Rana Estate',
#  'Punjab Associates',
#  'Forces Properties',
#  'Punjaab Estates',
#  'Valo Marketing',
#  'Ibraheem Associates',
#  'Al-Ghous Real Estate Management & Construction',
#  'Mughal Estate & Builders',
#  'Musa Enterprises',
#  'Premier Properties',
#  'Well Known Properties',
#  'Karachi Real Estate Investment Trust',
#  'Universal Estate & Builders',
#  'Property Master',
#  'United Real Estate',
#  'Memon Real Estate',
#  'Vigilant Property Solutions',
#  'Patel Builders',
#  'Estate 1. com',
#  'Guide Line Real Estate',
#  'Khatwani Estate',
#  'Entrepreneur Real Estate',
#  'Shah Zain Associates',
#  'Property Panel',
#  'Al Karam Property',
#  'National Property Advisor',
#  'Kings & Queens',
#  'Top Line Real Estate Consultants',
#  'Farhan Real Estate',
#  'MB Estate & Builders',
#  'Property Connect',
#  'H. A Estate & Builders',
#  'Zaka Real Estate',
#  'Jinnah Associates',
#  'Vital Estate',
#  'The Property Lounge',
#  'Rana Estate Agency',
#  'Harum Real Estate & Builders',
#  'Aim Real Estate',
#  'Farhan Enterprises',
#  'Property Hub',
#  'BEC Consultants',
#  '786 Estate',
#  'Professionals Real Estate Consultants & Builder',
#  'Property Valley',
#  'Altamash Estate & Construction',
#  'Al Ghazi Property',
#  'Awais Builders and Property Advisor',
#  'A To Z Group',
#  'TM Associates',
#  'Business Links',
#  'Almo Estate',
#  'Indus Estate And Builders',
#  'Pakistan Property Today',
#  'CAPITAL REALTY',
#  'Corporate Realtors',
#  'The Property Edge',
#  'Al Bashir Impex',
#  'M A Associates',
#  'Lasani Vision Real Estate',
#  'Aiman Estate',
#  'Findwell Real Estate & Developers',
#  'T Y C O O N   R E A L T O R S',
#  'Chughtai Associates',
#  'Gateway Properties',
#  'Al Madina Estate Experts & Marketing',
#  'Arazi Real Estate',
#  'Asia Builders & Real Estate',
#  'FB Builders & Real Estate Consultants',
#  'Paras Estates',
#  'Right Track Consultants',
#  'Pak Lafame Estate Realtor',
#  'A S Properties',
#  'AARCO Fazaia Authorized Dealer',
#  'Maniya Associates',
#  'Kokan Estate',
#  'Al Azmat Estate',
#  'The Property Company',
#  'Town Estate & Marketing',
#  'Land Masters Realty Investments',
#  'PMS Property Management Services',
#  'Sareer Estate and Builders',
#  'Estate Eyes',
#  'Savoy Estate',
#  'Hasne Estate',
#  'Mid Citi Enterprises',
#  'Kharian Estate',
#  'Zain Real Estate',
#  'Al-Wasay Associates',
#  '786 Real Estate',
#  'Globe Real Estate',
#  'Lodhi Estate',
#  'Personal Realtors Estate & Builders',
#  'Zameen Estate (R)',
#  'Matchless Estate & Builders',
#  'Apna Estate & Builders',
#  'Mubeen Estate',
#  'Gwadar Real',
#  'Ziara Estate & Builders',
#  'Combines Estate',
#  'Khyber Construction & Property Zone',
#  'JK Property',
#  'Shaikh Enterprises',
#  'Bali Enterprises',
#  'UPN (Universal Property Network)',
#  'Zisk Properties',
#  'Khawaja Enterprise',
#  "Ganatra's Real Estate & Property Advisor",
#  'Madni Enterprise',
#  'Aaraish Estate Agency',
#  'Margalla Gateway',
#  'Shapers Builders & Real Estate',
#  'Al Barka Property',
#  'Khawaja Corporation',
#  'Dawn Associates',
#  'Raja Real Estate',
#  'Paramount Property Solutions',
#  'Sky Land Estate',
#  'Al Tawakkal Enterprises',
#  'Pioneer Associates',
#  'Platinum Investments',
#  'Property Channel Real Estate',
#  'Property Prime Time',
#  'Bawany Real Estate & Builders',
#  'A N Associates',
#  'Nawaz Khan Enterprises',
#  'K. K Enterprises',
#  'Fortune Realtors',
#  'Khosa Estate & Builders',
#  'A. K Property & Builders',
#  'Hasnain Property',
#  'Al Hamdan Real Estate',
#  'Raabta Property Center And Builders',
#  'Desire Associates',
#  'Madni Estate',
#  'Arham Ali Property Consultants',
#  'Property Adviser & Builders',
#  'Nationwide Estate & Builders',
#  'Property Concern Real Estate Consultants',
#  'Samar Associates',
#  'Paragon Club Real Estate',
#  'Omer Associates',
#  'Royal Property Services',
#  'Karsaz Estate',
#  'Dreamland Associates & Dreams Builder',
#  'Karachi Estate',
#  'Karsaz Associates',
#  'Estate By State',
#  'KDF Enterprises',
#  'Modern Builders & Real Estate',
#  'Sadiq Sons Builders (Pvt) Ltd',
#  'Shafqat Real Estate & Builders',
#  'Al Meezan Properties',
#  'Asif Associates',
#  'Kamran Estate',
#  'Five Star Properties Real Estate Consultant',
#  'Imran Real developer Marketing',
#  'Progressive Services',
#  'Aamir Real Estate',
#  'Property Manager',
#  'Elite Homes',
#  'Al-Asar Properties',
#  'Paradise Enterprises',
#  'Ahsan Estate',
#  'Home 5 Real Estate Consultants',
#  'Jami Properties',
#  'Anwer Estate',
#  'Property Experts',
#  "Ash'hab Enterprises",
#  'Dream Land',
#  'Royal Estate',
#  'Property Time Real Estate Advisor',
#  'SahulatKar Properties',
#  'Abdullah Estate & Builders',
#  'International Estate & Builders',
#  'Chaudhary Estate & Traders',
#  'Ask Properties',
#  'Sealand Corporation',
#  'Chaudhary Associates',
#  'AS Group Real Estate',
#  'Ali Associates',
#  'Harmain Estate',
#  'Meritorious Group',
#  'Property Expert',
#  'Abdul Aziz Estate & Builders',
#  'ACE Real Estate',
#  'J&Z Real Estate',
#  'The Contractors',
#  'Perwani Associates',
#  'Property Prime Line Real Estate Advisor & Consultant',
#  'Deal Associates Property Dealer And Advertisors',
#  'Bhatti Enterprise',
#  'FA Property',
#  'Mian Muhammad Tahir Farooq & Construction',
#  'Al Samad Real Estate & Builders',
#  'Real Estate Max',
#  'Royal Corporation',
#  'Legend Estates',
#  "Al Mu'min Estate (PVT) LTD",
#  'Fair Consultants',
#  'Curvestone Construction',
#  'Worldcon Real Estate',
#  'Abdullah Real Estate',
#  'RNA Associate & Buliders',
#  'Jillani Estate',
#  'JS Estate Marketing',
#  'Ya Rab Associates',
#  'Haram Estate & Builders',
#  'Malik & Malik Estate  Builders',
#  'Mubashir Real Estate',
#  'Wahaj Khan Associates',
#  'Essex Solutions Real Estate',
#  'Value Investments',
#  'AMA International',
#  'PRIME INNOVATIVE ARCHITECTURE & ESTATE',
#  'Hamza Enterprises',
#  'Urban Properties Pk',
#  'Dean Sons Property Solutions',
#  'Estate Ways',
#  'True Man Associates',
#  'Iqbal Associates',
#  'New Hira Estate',
#  'Maumar Consultancy',
#  'ATC PROPERTY LINKS  MARKETING',
#  'Aspire Enterprises',
#  'Pak Real Estate',
#  'MAVA Business Planners',
#  'Upland Enterprises',
#  'Shah Builders',
#  'JJ & Co. Estate Builders',
#  'Opportunity Estate',
#  'Jaidad Developers',
#  'AL Arz Estate & Builders',
#  'Moosa Estate Advisors & Builders',
#  'Shah Associates',
#  'Madina Estate',
#  'Estate Net',
#  'Farhan Associates (Warda Hamna)',
#  'Crown Estate & Builders',
#  'Investors Zone Real Estate & Builders',
#  'Uzair Property Advisor',
#  'Sundar Estate & Property Consultants',
#  'Property Zone',
#  'Safeway Estate & Builders',
#  'Suddhan Associates',
#  'Time Value Enterprises',
#  'Shan Estate Advisor',
#  'Property Royale',
#  'Qamer & Sons Associates',
#  'Mumtaz Associates',
#  'Jangda Estate',
#  'Sohni Estate & Marketing',
#  'Civic Estate',
#  'Property Planet',
#  'Bhatti Estate & Builders',
#  'Nadeem Estate & Builders',
#  'Smile Pakistan Network',
#  'TIAREC',
#  'Tycoon Estate And Builders',
#  'Business Communicator',
#  'Al Madina Estate Centre',
#  'SERANI ESTATE',
#  'Lahore Havalian Estate',
#  'Auckland Associates',
#  'Bin Sadiq Real Estate',
#  'Lucky Estate',
#  'Al Samad Real Estate',
#  'Saqib Estate',
#  'Bin Rauf Enterprises',
#  'Times Enterprise',
#  'METRO ESTATE & BUILDERS',
#  'Ibrahim Associate',
#  'UM Property Consultants',
#  'Khawaja & Sons',
#  'Al Kashan Estate',
#  'Defence Estate',
#  'Elite Properties',
#  'Mufaddal Properties',
#  'Al Sadat Associates',
#  'Abdul Aleem Associates Estate & Builders',
#  'King Real Estate Consultant & Builders',
#  'Bilal Properties',
#  'Tooba Estate',
#  'Estate World',
#  'HN Consultant & Developers',
#  'Mehmood Estate',
#  'Kamran Associates',
#  'Al Shaikh Corporation',
#  'Fauji Estate & Builders',
#  'Malik Tufail Estate Advisor',
#  'Property Resources',
#  'Property Corner Real Estate Consultants',
#  'Sehgol Estate',
#  'Combat Builders & Property Advisors',
#  'Al Jazeera Property Zone',
#  'Al Naffay Associates',
#  'Hassan Property Links',
#  'Mazhar Enterprises Real Estate',
#  'A. R Memon Estate',
#  'Emkay Consultants',
#  'Athar Associates',
#  'Shakir Associates',
#  'Kainat Associates',
#  'Noble Enterprises',
#  'Seven 8 Six',
#  'Twin Cities Real Estate',
#  'E Z Estate',
#  'M M Estate & Builders',
#  'Property Links',
#  'Property Square',
#  'Al Noor Real Estate',
#  'Mian Property Dealer',
#  'Muslim Real Estate Agency',
#  'IR Real Estate And Builders',
#  'SnS Solutions',
#  'Malik Enterprises',
#  'Siddiqui and Siddiqui Estate',
#  'Hayat Real Estate',
#  'Starland PROPERTIES',
#  'Lyallpur Estate & Builders',
#  'ATTARI ASSOCIATES',
#  'Shazli Estate & Builders',
#  'Al Umar Associates',
#  'Danyial Estate & Builders',
#  'Mark & Build Property Consultants & Developers',
#  'R B Real Estate & Builders',
#  'Bukhari Properties',
#  'Falcon Askari Enterprises',
#  'The Mark Associates',
#  'Town Estate',
#  'Al Hamd Estate Link And Builders',
#  'Uppals Builders  Developers',
#  'Prime Estate',
#  'Ali Property Advisor',
#  'Z. N Builders & Real Estate',
#  'Jagir Real Estate Consultants',
#  'Sahara Properties',
#  'City Estate & Builders',
#  'Property Solutions',
#  'Khattak Property Advisor',
#  '4 Season Real Estate',
#  'Al Umer Real Estate & Builders',
#  'Saad Property Consultants',
#  'Swiss Property Investment',
#  'Satti Associates',
#  'GH Group',
#  'Kaizen Consulting & Services',
#  'AH Marketing',
#  'Sky Lap Builders & Real Estate',
#  'Ujala Pakistan',
#  'Dial 4 Property',
#  'Khan Brothers Real Estate',
#  'Bilal Estate Agency',
#  'Rajput Estate',
#  'Rehmans Real Estate Consultants',
#  'Al-Hafiz Estate',
#  'Atta Associates & Builders',
#  'MK Property',
#  'Signature Properties',
#  'Al Mursaleen Real Estate & Builders',
#  'Suleman Associates',
#  'Mairaj Associates Real Estate & Builders',
#  'Iqbal Bhai Builders & Estates',
#  'Nazir Estate',
#  'Hotline Associates',
#  'AK Properties',
#  'Asasay Estate',
#  'Ali Estate Advisors',
#  'Jarrar Builders & Developers',
#  'Heaven Estate',
#  'ST Enterprises',
#  'Estate Era',
#  'Grace Land Advisors',
#  'National Property Consultant',
#  'Swat Associates',
#  '101 Real Estate & Builders',
#  'Al-Qasim Estate & Developers',
#  'AA Real Estate Agent',
#  'ILand',
#  'H. K Associates & Builders',
#  'GS Real Estate',
#  'Home Key Real Estate',
#  'Kashif Estate',
#  'CITI Associates',
#  'Khurram Estate & Builders',
#  'Mian Estate',
#  'Prime Landmark',
#  'Khanani Estate',
#  'Investment Estate',
#  'Gillani Real Estate',
#  'Al Buraq Real Estate Advisor',
#  'Al Kareem Real Estate',
#  'Etmaad Estate',
#  'Miland Builders',
#  'Sarmaya Real Estate',
#  'Madina Property Channel',
#  'Haseeb Enterprises',
#  'Property Ideas',
#  'Euro Estate',
#  'Mandiyal Estate',
#  'Rajpoot Estate',
#  'The Brokers Real Estate & Marketing',
#  'Hotlink Associates',
#  'Right Move',
#  'Adeel Estate',
#  'Rao Estate & Builders',
#  'Zmaka Estate (Land Management Solutions)',
#  'Mount Pakistan',
#  'Furqan Estate',
#  'Bismillah Associates',
#  'Farhat Estate',
#  'Estate Enterprises',
#  'Sidra Enterprises',
#  'Afzal Associates',
#  'Sheikh PG Marketing',
#  'Vertex International',
#  'Probiz Enterprises',
#  'Marzs Group',
#  'Zamil Real Estate',
#  'Mashallah Associates & Biulders',
#  'Home Square',
#  'Green Wood Estate',
#  'Saqib Associates',
#  'Ammar Associates',
#  'Razmak Associates',
#  'Estate Links',
#  'One 2 One Property Linker',
#  'Tiwana Associates',
#  'Al Haram Estate Advisor',
#  'Saqib Real Estate',
#  'The Realtors Marketing',
#  'The Circle Real Estate Consultant',
#  'Dynamic Real Estate',
#  'Mian Estate & Builders',
#  'Estate Plus',
#  'Real Spot Estate',
#  'N M Associates',
#  'Mustifa Estate',
#  'Linkers Realty',
#  'Ali Estate Agency',
#  'Mazhar Associates',
#  'Faisal Rehman estate',
#  'Estate Marketers',
#  'Al Rasheed Property',
#  'Concept Estate',
#  'Anss Marketing',
#  'JJS Enterprises',
#  'Lucky Corner Estate Agency',
#  'Capital Marketing',
#  'Baypoint Property Consultants',
#  'Turab Marketing',
#  'Global Real Estate',
#  'Casa Estate & Developers',
#  'Islam Estate',
#  'Estate Forum',
#  'Estate Biz',
#  'The Estate Arts',
#  'Kashmir Traders Multi Services',
#  'Pak Real Estate & Builders',
#  'Kaghan Properties',
#  '4M Enterprises',
#  'Punjab Property Consultant',
#  'Syed Bhai Estate & Builders',
#  'Central Estate',
#  'Shahzad Estate & Builders',
#  'Affan Enterprises',
#  'Defence Real Estate',
#  'Maula Group Real Estate Consultants & Developers',
#  'Punjab Estate & Developers',
#  'Ibtisam Estate',
#  'Shelter Group',
#  'A. K Real Estate',
#  'Mia Noor Real Estate',
#  'Capital Estate  Construction',
#  'Heral Properties Real Estate Consultant',
#  'ZB Associate',
#  'National Properties',
#  'The Estate Master',
#  'Rahim Associates',
#  'Hasnain Marketing & Consultants',
#  'Pakistan Holdings',
#  'Carewel Real Estate Consultants',
#  'Realtors Destiny',
#  'Free Men Estate & Builders',
#  'Shahbaz',
#  'My Properties',
#  'Aleem Associates',
#  'Online Enterprises',
#  'Iconic Real Estate',
#  'Kashmir Homes Associates',
#  'Hafeez Real Estate',
#  'Midland Estate & Builders',
#  'Estate Legends',
#  'MAYMAR REAL ESTATE',
#  'Abbas Real Estate & Builders',
#  'Estate Unit',
#  'North Estate',
#  'ESTATE Forward',
#  'Jiwani Estate',
#  'Al Fatima Properties',
#  'Sharjeel Real Estate',
#  'Pak Estate',
#  'Habib Estate',
#  'Ayaan Real Estate & Builders',
#  'Land Spot Real Estate & Builders',
#  'HBF Estate',
#  'Eigenschaft Consultant',
#  'Modern Shelters',
#  'Al Rehmat Real Estate & Builders',
#  'Mian Rafique Estate',
#  'Property Bank Real Estate',
#  'Umar Estate',
#  'Green World Real Estate',
#  'Accurate Estate & Builders',
#  'Hasher Associates',
#  'Bismillah Property (Real Estate Dealer)',
#  'Earth Real Estate & Developers',
#  'Fine Associates & Constructions',
#  'Gondal Estate',
#  'Aashyana Property Consultant',
#  'Sub Ki Property',
#  'Mian International',
#  'Rahi Builders',
#  'Al Madina Real Estate',
#  'Potohar Builders',
#  'Eagle Eye Estate',
#  'Safari Estate',
#  'Al Sadiq Estate',
#  'Azhar Builders & Real Estate',
#  'Al-Kabir Experts Real Estate Consultants',
#  'Fareed Estate & Builders',
#  'Smart Developers',
#  'Iconic Citi Estates',
#  'Mujahid Estate Advisor',
#  'AAA Property Advisor',
#  'Jaidad Real Estate Professionals',
#  'A. B Estate',
#  'Palm Estate',
#  'Al Aziz Real Estate',
#  'Galaxy Estate',
#  'Watan Property',
#  'Bin Wahid Associates',
#  'Profit Ole Estate',
#  'EL-One Real Estate',
#  'Abrar Estate Services & Builders',
#  'Ideal Deal Real Estate & Builders',
#  'BSM Global Real Estate',
#  'Usman Associates',
#  'Property Deals',
#  'Land Mark Properties',
#  'Real Estate Gallery',
#  'Future Value Enterprises',
#  'Mazhar Real Estate',
#  'Zamek Enterprises',
#  'Rizwan Property',
#  'Mian Estate Agency',
#  'Pak Estate & Engineering Solutions',
#  "Yousaf Bhai's Real Estate",
#  'Al Majeed Enterprises',
#  'Property Point',
#  'Silicon Associates',
#  'Pardesi Real Estate',
#  'Sajjad Ali Estate Agency',
#  'Dream Vision Property Network',
#  'Zeeshan Associates',
#  'Fine Estate',
#  'Hussain Builders and Associates',
#  'Land Masters',
#  'Safehand Marketing',
#  'Carbon8 Real Estate & Marketing',
#  'Destiny Real Estate & Builders',
#  'Al- Jannat Real Estate',
#  'Syed Muhammad Estate & Builders',
#  'Adil Constructions Builders & Real Estate',
#  'Talha Estate',
#  'Al Falah Associates',
#  'Burki Estate & Marketing',
#  'Big Ben Estate',
#  'Al Ghani Properties',
#  'Muhammad Real Estate',
#  'Al Rafay Associates',
#  'Master Properties',
#  'Al Fateh Estate & Builders',
#  'Deal Makerz',
#  'Far Side Associates',
#  'Sehar Enterprises',
#  'Al Kareem Enterprises',
#  'Jhangir Estate & Builders',
#  'Nassar Property Marketing',
#  'Land Linkers real Estate & Marketing',
#  'Fazal Real Estate',
#  'Al- Buraq Property Concern',
#  'Abu Hamza Estate',
#  'Abdul Razaq Property Dealer & Builders',
#  'Lahore Gwadar Real Estate',
#  'Madina Real Estate',
#  'AKT Estate & Builders',
#  'KN Associates',
#  'Madina Associates & Advisors',
#  'AL-Wasay Real Estate Consultants',
#  'Grace Properties',
#  'The One Enterprises',
#  'City Real Estate',
#  'Pakistan Real Estate & Builders',
#  'Farooq Bhai Real Estate',
#  'Marhaba Estate & Builders',
#  'Marks Property Management',
#  'Waheed Estate & Builders',
#  'Azan Associates',
#  'Mughal Estate',
#  'Value Homes',
#  'IPS Pvt (Ltd)',
#  'Real Estate One',
#  'Bright Homes Property Consultants & Builders',
#  'Estate Expert',
#  'Sardar Associates Real Estate & Builders',
#  'Property Chain',
#  'Bismillah Estate & Builder',
#  'Al Hafeez Real Estate',
#  'Fortune Deals',
#  'Al Ghazi Estate & Builders',
#  'Property Advisor',
#  'Al Naveed Associates',
#  'Al Makkah Estate',
#  'Friends Associates',
#  'Mashal E Madina Real Estate',
#  'K K Real Estate',
#  'Yasir Associates & Developer',
#  'SK Real Estate & Builders',
#  'Bilsmark Realty',
#  'Al Fatima Corporation',
#  'Aitemaad Property',
#  'Faisalabad Realtors',
#  'Zain Associates',
#  'Sarhad Property And Consultant',
#  'Syed Brothers PVT LTD (Ph: 2 DHA)',
#  'Relations',
#  'Fajar Real Estate',
#  'Kargil Estate & Builders',
#  'Bao Estate',
#  'Alpha Investment',
#  'Concept Real Estate',
#  'SAS Real Estate & Construction',
#  'J & B Associates',
#  'Saad Associate',
#  'Gharonda Real Estate & Builders (Pvt) Ltd',
#  'Azan Real State Advisor & Builders',
#  'Al Wahab Consultants & Builders',
#  'Bukhari Builders & Real Estate',
#  'Imlaak',
#  'MB Associates',
#  'Mahaar Real Estate',
#  'Insaf Real Estate & Builders',
#  'Property Perfect Time',
#  'Bombay Estate Agency',
#  'Property Bank Islamabad',
#  'Orakzai Real Estate & Builders',
#  'Hassan Traders',
#  'Al Meezan Real Estate',
#  'Excellence Real Estate',
#  'Fk Property',
#  'I. S Builders',
#  'HA Associates',
#  'City Properties & Builders',
#  'Pak Associates',
#  'Zahid Brothers',
#  'Real Estate Network',
#  'Eman Estate Property Consultant',
#  'Al-Asar International  Property',
#  'Al Kareem Properties',
#  'Property Time',
#  'Ahmed Ejaz Real Estate',
#  'TransInvest International',
#  'Al Noor Associates',
#  'Madina Real Estate & Builders',
#  'Map Properties',
#  'Locations Property And Construction',
#  'Cavalry Estate',
#  'Skyhigh Enterprises',
#  'Al Muqeet Builders & Developers',
#  'AL Jabal Estate',
#  'Kashir Enterprises & Co.',
#  'Shalimar Marketing Group',
#  'SJ Properties',
#  'Chishti Real Estate Advisors & Builders',
#  'SARCO (SA Rana And Co)',
#  'Prime Lands Real Estate & Consultant',
#  'Sheikh Corporation',
#  'Ettihad Builders And Property Advisor',
#  'Prime Real Estate & Builders',
#  'Soneri Estate',
#  'Hadi Associates',
#  'Abad Estate',
#  'Seth Corporation',
#  'Manaf Associates',
#  'Chuhan Associates',
#  'Prime Homes Property Consultant & Builders',
#  'City Property',
#  'Hamdaan Associates Real Estate Consultants  Builders',
#  'Feroze Associate',
#  'Property. com Real Estate & Builders',
#  'Rehman Estate Linkers',
#  'Emlak Real Estate',
#  'Pak Enterprises',
#  'Worthy Real Estate & Builders',
#  'AAS Properties',
#  'Abdullah Property Consultants',
#  'Hussain Estate Agency',
#  'Supreme Estate',
#  'Zainab Associates',
#  'Khan Properties',
#  'Khatri Properties',
#  'Noorani Associate',
#  'Etihad Property Consultant',
#  'ZTB Associates',
#  'Friends Property Advisor & Builders',
#  'Global Links',
#  'Khalid Ghazi Real Estate & Builders',
#  'Links Up Real Estate',
#  'Future Planners',
#  'Al Syed Associates',
#  'MI Associates',
#  'A R Associates',
#  'Mahenti Estate',
#  'Accomodators',
#  'Property Concept',
#  'Akhtar Associates',
#  'A&A Capital Associates',
#  'Gemini Developers',
#  'S & S Consultancy',
#  'Hassan Estate',
#  'Hameed Associates  Builders',
#  'Al Rehman Estate',
#  'Perfect Properties & Developers',
#  'Anmol Estate Linker',
#  'VIP Properties',
#  'Land Master Builders and Property Advisors',
#  'S & F Associates',
#  'Hajveri Property Corner',
#  'Al Aamir Estate',
#  'Bega Properties',
#  'Thanvi Associate',
#  'The Land Advisor',
#  'Mian Shahid Associate',
#  'AL Meezan Property Center',
#  'Estate Vision',
#  'Best Deal Real Estate Consultant',
#  'Property Hub Real Estate Consultants & Builders',
#  'Saad Property Consultant',
#  'Syed Associates & Builders',
#  'Land Masters Real Estate & Builders',
#  'Sultani Estate Adviser',
#  'Imran Real Estate',
#  'Green Land Property Gallery',
#  'Investor Guide Estate & Builders',
#  'Nazim Corporation',
#  'Akhlaq Associates',
#  'TJ Property',
#  'Memon Estate',
#  'Hammad Associates',
#  'Hanif Estate',
#  'Alpha Properties',
#  'Pearl Associates',
#  'Warraich Associates',
#  'Dreams World',
#  'HIZ Hope Investment Zone',
#  'As Enterprises',
#  'Umer Estate Adviser & Builders',
#  'Dream Land Real Estate',
#  'Talagang Estate & Builders',
#  'Saiban Associates',
#  'Cosmic Associates',
#  'Tameer Real Estate Consultant And Builders',
#  'Rehbar Estate & Builders',
#  'Razwan Associates',
#  'Hasnain Associates',
#  'Sandhu Brothers Estate Advisor',
#  'Chaudhry Associates',
#  'Ittehad Property',
#  'Zeeshan Property Consultant',
#  'Touheed Real Estate',
#  'Karakoram International Real Estate & Builders',
#  'Nation Associates',
#  'Al Najaf Estate Agency',
#  'Allied Marketing',
#  'Royal Properties Real Estate & Builders',
#  'Al Hamd Associate',
#  'Faisal Estate',
#  'LUCKY ASSOCIATES',
#  'AAJ REAL STATE',
#  'Masha Allah Associate And Marketing',
#  'Karpalani Associates',
#  'M Y Real Estate',
#  'Realty Access',
#  'Zaman Associates and Builders',
#  'Prime Links Real Estate & Builders',
#  'Taamirat Property & Construction',
#  'A. D Associates',
#  'AL Falah Estate & Builders',
#  'A R Homes',
#  'Samama Estate',
#  'Nasar Builders & Sons',
#  'Ittehad Estates',
#  'New Lahore Estate and Builders',
#  'Estate Castle',
#  'Al Haram Estate & Construction',
#  'Imtiaz Enterprises',
#  'Heavens Deal Real Estate',
#  'Forte Associates',
#  'ISB Property Marketing',
#  'Marriott Estate & Builders',
#  'Usman Sheikh Estate Advisor',
#  'Alrehman Builders & Real Estate',
#  'Rukh e Sana Real Estate',
#  'Malik Real Estate & Builders',
#  'Minhas Property',
#  'Al-Hussnain Real Estate',
#  'Cantt Estate',
#  'Sheranwala Estate & Builders',
#  'Deluxe Homes',
#  'Al Bilal Estate & Builders',
#  'Al-Malik Estate Advisor & Builders',
#  'Star Property',
#  'Uptrade Estate',
#  'Find Homes Real Estate',
#  'Pakistan Estate Links',
#  'Al Ahram Property Advisor',
#  'Capital Property Advisors',
#  'Advice Associates',
#  'Al Moiz Estate Advisor & Builders',
#  'Subhan Estate Advisor',
#  'Green Wood Estate & Builders',
#  'Jannat Property Network',
#  'AHR & Company',
#  'Al Mustafa Estate & Builders',
#  'Kath Real Estate Marketing',
#  'Wahid Estate Agency',
#  'Hadi Estate Servies',
#  'Asia Properties',
#  'Property Insight',
#  'Al Wahab Estate & Builders',
#  'Pak Zameen Estate',
#  'S. S Enterprises',
#  'Sohail Properties',
#  'S&N Property Consultants & Builders',
#  'Khilji Associates',
#  'Realco',
#  'AAK Group Builders & Contractors',
#  'Fine Realty Property Consultant',
#  'Aklins Properties',
#  'Southern Investment',
#  'Abasin Real Estate',
#  'Pakistan Estates',
#  'Ghousia International',
#  'Rehman Real Estate',
#  'Al Burraq Real Estate & Builders',
#  'H&S Pvt Ltd',
#  'Khalid & Sons Property',
#  'Pak Builders & Estate Advisors (Pvt. ) Limited',
#  'Icon Properties',
#  'Abdullah Real Estate & Marketing',
#  'S K Real Estate',
#  'Yammama Real Estate & Builders',
#  'Usman Contractor & Builders',
#  'Shaheen Estate & Builders',
#  'MRG Real Estate',
#  'Al-Madina Estate',
#  'Raja Hameed & Sons',
#  'Moti Estate & Builders',
#  'CivilNest',
#  'Sulman Real Estate & Builders',
#  'Rehman Estate Developers',
#  'Mudassar Estate & Builders',
#  'Estate Land & Builders (R)',
#  'Rehan Estate & Buliders',
#  'High Deals Real Estate',
#  'Syed Real Estate & Builders',
#  'Waseem Sons Enterprises Real Estate Consultants & Builders',
#  'Shaheen Builders & Marketing',
#  'Shahzain Associates',
#  'Memon Property',
#  'Al Israr Estate & Builders (PVT) LTD.',
#  'Kalim Real Estate',
#  'Islamabad Real Estate',
#  'Shahid Property Advisors',
#  'Bhaloot Property Advisor',
#  'Spirals Estate & Builders',
#  'Ahmed Associates & Constructor',
#  'Ibraheem Brothers Real Estate',
#  'Al Raheem Estate & Builders',
#  'Lajpal Real Estate Consultant Renovation  Interior',
#  'Yards & Acres',
#  'AMS Group Daata Estate',
#  'SH Real Estate & Builders',
#  'Al Aziz Estate',
#  'Prince Associates',
#  'Mattloob Estate Agency',
#  'Al Ghazi Real Estate',
#  'The Managers Group Real Estate & Builders',
#  'Hum Real Estate',
#  'Younus Zubair Associates',
#  'Zaka Estate',
#  'Amir Brothers Associates Lucknow Estate & Builders',
#  'Shah Estate & Associate',
#  'AL Farrukh Real Estate & Builders',
#  'Fazal Builders and Co.',
#  'Three Brothers Real Estate',
#  'Al Quaid Enterprises',
#  'Qalam Sher Associates',
#  'Tayyab Associates Estate & Builders',
#  'Manzoor Associates',
#  'Property Exchange',
#  'Khalil Sons Real Estate & Builders',
#  'Al Bashir Estate Centre',
#  'Property Club',
#  'Arif Associates',
#  'Younas & Sons Enterprises Real Estate',
#  'Adeel Associates',
#  'Kayem Real Estate',
#  'Dasti Assiciates',
#  'Amin Son Real Estate',
#  'Al Rehman Enterprises',
#  'Un Brother Estate',
#  'Sardar Associates',
#  'Hunza Estate',
#  'Al Hadi Estate',
#  'Al Aqsa Estate',
#  'Classic Real Estate',
#  'Mariner Property Services',
#  'Al Qaim Associate',
#  'ESTATE VENTURE',
#  'Zafran Real Estate',
#  'Elahi Real Estate Advisor  Builders',
#  'Lands King',
#  'Builders Emporium Real Estate',
#  'Baig Real Estate',
#  'Mohsini Property Hub',
#  'Rehn Basera Property Advisor',
#  'Havalian Estate',
#  'Mazhar Estate',
#  'Life Style Associates',
#  'Huzaifa Hammad Associates',
#  'Abdul Wasay Real Estate',
#  'Green Compound Real Estate & Builders',
#  'Estate & Estate',
#  'Burhan Estate And Advisor',
#  'Property Construction Masters',
#  'Saqib Nawaz Associates',
#  'Usman Builders',
#  'Saddiqia Real Estate & Builders',
#  'Fahad Associates',
#  'Red Bricks Properties',
#  'Mahaar Real Estate Advisor',
#  'Connect Property Marketing',
#  'Freedom Estate & Builders',
#  'Ali Estate Corporation',
#  'Zahid Estate',
#  'Al Makkha Estate Advisor',
#  'Hafiz Real Estate Advisor',
#  'Asif Enterprises',
#  'Hussain Warsi Estate & Builders',
#  'Sentinel Real Estate',
#  'MZ Associates',
#  'Rahmat Enterprises',
#  'Abdalian Associates',
#  'Z. A. Z Real Estate Marketing (Pvt) Ltd.',
#  'Citizen Real Estate',
#  'Green Heaven Property Advisor and Builders',
#  'Al Muqeet Estate',
#  'Rajpoot Property Advisor',
#  '7 Estate & Builder',
#  'Yam Group',
#  'Razi Associates',
#  'Anabia Associate & Builders',
#  'Royal Properties',
#  'Noor Property Solution',
#  'Jaidaad The Real Estate',
#  'Green View Property & Construction Centre',
#  'Al Naafay',
#  'Connect Marketing Real Estate',
#  'Meezan Estate',
#  'MA Real Estate Consultant & Builders',
#  'Ideal Associates',
#  'Al Asar Associates',
#  ...]

# %%
data['agency'].fillna('self',inplace=True)
data['agent'].fillna('self',inplace=True)

# %%
data.isnull().sum()
# Out:
# property_type    0
# price            0
# location         0
# city             0
# province_name    0
# latitude         0
# longitude        0
# baths            0
# purpose          0
# bedrooms         0
# date_added       0
# agency           0
# agent            0
# Area Type        0
# Area Size        0
# dtype: int64

# %%
data1=data.copy()

# %%
data1.duplicated().sum()
# Out:
# 9409

# %%
data1.drop_duplicates(inplace=True)
data1.duplicated().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122436 entries, 0 to 122435
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_type  122436 non-null  object
#  1   price          122436 non-null  int64
#  2   location       122436 non-null  object
#  3   city           122436 non-null  object
#  4   province_name  122436 non-null  object
#  5   latitude       122436 non-null  float64
#  6   longitude      122436 non-null  float64
#  7   baths          122436 non-null  int64
#  8   purpose        122436 non-null  object
#  9   bedrooms       122436 non-null  int64
#  10  date_added     122436 non-null  object
#  11  agency         122436 non-null  object
#  12  agent          122436 non-null  object
#  13  Area Type      122436 non-null  object
#  14  Area Size      122436 non-null  float64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 14.0+ MB

# %%
data1.head(1)
# Out:
#   property_type     price location       city      province_name  latitude  \
# 0          Flat  10000000     G-10  Islamabad  Islamabad Capital  33.67989
#
#    longitude  baths   purpose  bedrooms  date_added agency agent Area Type  \
# 0   73.01264      2  For Sale         2  02-04-2019   self  self     Marla
#
#    Area Size
# 0        4.0

# %%
data1['date_added']=pd.to_datetime(data1['date_added'])

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113027 entries, 0 to 122435
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   property_type  113027 non-null  object
#  1   price          113027 non-null  int64
#  2   location       113027 non-null  object
#  3   city           113027 non-null  object
#  4   province_name  113027 non-null  object
#  5   latitude       113027 non-null  float64
#  6   longitude      113027 non-null  float64
#  7   baths          113027 non-null  int64
#  8   purpose        113027 non-null  object
#  9   bedrooms       113027 non-null  int64
#  10  date_added     113027 non-null  datetime64[ns]
#  11  agency         113027 non-null  object
#  12  agent          113027 non-null  object
#  13  Area Type      113027 non-null  object
#  14  Area Size      113027 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(3), object(8)
# memory usage: 13.8+ MB

# %%
data1.head(5)
# Out:
#   property_type     price     location       city      province_name  \
# 0          Flat  10000000         G-10  Islamabad  Islamabad Capital
# 1          Flat   6900000         E-11  Islamabad  Islamabad Capital
# 2         House  16500000         G-15  Islamabad  Islamabad Capital
# 3         House  43500000    Bani Gala  Islamabad  Islamabad Capital
# 4         House   7000000  DHA Defence  Islamabad  Islamabad Capital
#
#     latitude  longitude  baths   purpose  bedrooms date_added         agency  \
# 0  33.679890  73.012640      2  For Sale         2 2019-02-04           self
# 1  33.700993  72.971492      3  For Sale         3 2019-05-04           self
# 2  33.631486  72.926559      6  For Sale         5 2019-07-17           self
# 3  33.707573  73.151199      4  For Sale         4 2019-04-05           self
# 4  33.492591  73.301339      3  For Sale         3 2019-07-10  Easy Property
#
#                                           agent Area Type  Area Size
# 0                                          self     Marla        4.0
# 1                                          self     Marla        5.6
# 2                                          self     Marla        8.0
# 3                                          self     Kanal        2.0
# 4  Muhammad Junaid Ceo Muhammad Shahid Director     Marla        8.0

# %%
Area_in_marla=data1[['Area Type','Area Size']].apply(lambda x: x['Area Size']*20 if x['Area Type'] in ['Kanal'] else x, axis=1)
Area_in_marla.drop(['Area Type'],axis=1,inplace=True)
Area_in_marla.rename(columns={'Area Size':'Area_in_Marla'},inplace=True)
data1=pd.concat([data1,Area_in_marla],axis=1)
data1
# Out:
#         property_type     price         location        city  \
# 0                Flat  10000000             G-10   Islamabad
# 1                Flat   6900000             E-11   Islamabad
# 2               House  16500000             G-15   Islamabad
# 3               House  43500000        Bani Gala   Islamabad
# 4               House   7000000      DHA Defence   Islamabad
# ...               ...       ...              ...         ...
# 122431  Upper Portion     35000  Khayaban Colony  Faisalabad
# 122432          House     50000  Khayaban Colony  Faisalabad
# 122433  Upper Portion     50000     Saeed Colony  Faisalabad
# 122434  Upper Portion     50000      Madina Town  Faisalabad
# 122435  Upper Portion     25000       Susan Road  Faisalabad
#
#             province_name   latitude  longitude  baths   purpose  bedrooms  \
# 0       Islamabad Capital  33.679890  73.012640      2  For Sale         2
# 1       Islamabad Capital  33.700993  72.971492      3  For Sale         3
# 2       Islamabad Capital  33.631486  72.926559      6  For Sale         5
# 3       Islamabad Capital  33.707573  73.151199      4  For Sale         4
# 4       Islamabad Capital  33.492591  73.301339      3  For Sale         3
# ...                   ...        ...        ...    ...       ...       ...
# 122431             Punjab  31.427272  73.135886      0  For Rent         0
# 122432             Punjab  31.427272  73.135886      0  For Rent         0
# 122433             Punjab  31.434925  73.129199      0  For Rent         0
# 122434             Punjab  31.417640  73.120401      0  For Rent         0
# 122435             Punjab  31.421993  73.117657      0  For Rent         0
#
#        date_added               agency  \
# 0      2019-02-04                 self
# 1      2019-05-04                 self
# 2      2019-07-17                 self
# 3      2019-04-05                 self
# 4      2019-07-10        Easy Property
# ...           ...                  ...
# 122431 2019-07-03  Azeem Estate Agency
# 122432 2019-07-03  Azeem Estate Agency
# 122433 2019-07-03  Azeem Estate Agency
# 122434 2019-07-03  Azeem Estate Agency
# 122435 2019-07-03  Azeem Estate Agency
#
#                                                agent Area Type  Area Size  \
# 0                                               self     Marla        4.0
# 1                                               self     Marla        5.6
# 2                                               self     Marla        8.0
# 3                                               self     Kanal        2.0
# 4       Muhammad Junaid Ceo Muhammad Shahid Director     Marla        8.0
# ...                                              ...       ...        ...
# 122431               Azeem Amjad, Amjad Hussain Shah     Kanal        1.0
# 122432               Azeem Amjad, Amjad Hussain Shah     Marla       13.0
# 122433               Azeem Amjad, Amjad Hussain Shah     Marla       10.0
# 122434               Azeem Amjad, Amjad Hussain Shah     Kanal        1.0
# 122435               Azeem Amjad, Amjad Hussain Shah     Marla        7.0
#
#         Area_in_Marla
# 0                 4.0
# 1                 5.6
# 2                 8.0
# 3                40.0
# 4                 8.0
# ...               ...
# 122431           20.0
# 122432           13.0
# 122433           10.0
# 122434           20.0
# 122435            7.0
#
# [113027 rows x 16 columns]

# %%
data2=data1.copy()

# %%
sns.heatmap(data2.corr(),annot=True)
# Out:
# <ipython-input-32-6db4094ef65d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data2.corr(),annot=True)
# <Axes: >

# %%
data2.drop(['Area Type','Area Size'],axis=1,inplace=True)

# %%
data2.head()
# Out:
#   property_type     price     location       city      province_name  \
# 0          Flat  10000000         G-10  Islamabad  Islamabad Capital
# 1          Flat   6900000         E-11  Islamabad  Islamabad Capital
# 2         House  16500000         G-15  Islamabad  Islamabad Capital
# 3         House  43500000    Bani Gala  Islamabad  Islamabad Capital
# 4         House   7000000  DHA Defence  Islamabad  Islamabad Capital
#
#     latitude  longitude  baths   purpose  bedrooms date_added         agency  \
# 0  33.679890  73.012640      2  For Sale         2 2019-02-04           self
# 1  33.700993  72.971492      3  For Sale         3 2019-05-04           self
# 2  33.631486  72.926559      6  For Sale         5 2019-07-17           self
# 3  33.707573  73.151199      4  For Sale         4 2019-04-05           self
# 4  33.492591  73.301339      3  For Sale         3 2019-07-10  Easy Property
#
#                                           agent  Area_in_Marla
# 0                                          self            4.0
# 1                                          self            5.6
# 2                                          self            8.0
# 3                                          self           40.0
# 4  Muhammad Junaid Ceo Muhammad Shahid Director            8.0

# %%
data2.to_csv('EDA_dataset.csv')

# %%
data2.drop(['province_name',
            'agent',
            'agency',
            'date_added',
            'longitude',
            'latitude'],
           axis=1,
           inplace=True)
data2.head()
# Out:
#   property_type     price     location       city  baths   purpose  bedrooms  \
# 0          Flat  10000000         G-10  Islamabad      2  For Sale         2
# 1          Flat   6900000         E-11  Islamabad      3  For Sale         3
# 2         House  16500000         G-15  Islamabad      6  For Sale         5
# 3         House  43500000    Bani Gala  Islamabad      4  For Sale         4
# 4         House   7000000  DHA Defence  Islamabad      3  For Sale         3
#
#    Area_in_Marla
# 0            4.0
# 1            5.6
# 2            8.0
# 3           40.0
# 4            8.0

# %%
data2['property_type'].unique()
# Out:
# array(['Flat', 'House', 'Penthouse', 'Farm House', 'Lower Portion',
#        'Upper Portion', 'Room'], dtype=object)

# %%
list(data2['location'].unique())
# Out:
# ['G-10',
#  'E-11',
#  'G-15',
#  'Bani Gala',
#  'DHA Defence',
#  'Ghauri Town',
#  'Korang Town',
#  'F-11',
#  'Diplomatic Enclave',
#  'F-6',
#  'B-17',
#  'PWD Housing Scheme',
#  'G-11',
#  'Bhara kahu',
#  'Garden Town',
#  'Koral Town',
#  'Soan Garden',
#  'Blue Area',
#  'F-7',
#  'I-16',
#  'E-7',
#  'Pakistan Town',
#  'Islamabad Expressway',
#  'G-8',
#  'Model Town',
#  'Multan Road',
#  'Eden',
#  'Gulberg',
#  'Allama Iqbal Town',
#  'Military Accounts Housing Society',
#  'EME Society',
#  'Izmir Town',
#  'Upper Mall',
#  'Cavalry Ground',
#  'Bahria Town',
#  'Askari',
#  'Bedian Road',
#  'Agrics Town',
#  'Chaman Park',
#  'Chungi Amar Sadhu',
#  'GOR',
#  'Karim Park',
#  'Cantt',
#  'Valencia Housing Society',
#  'Gulshan-e-Ravi',
#  'Al-Raheem Garden',
#  'Mateen Avenue',
#  'Paragon City',
#  'IEP Engineers Town',
#  'Muslim Town',
#  'Millat Town',
#  'Raza Abad',
#  'Satiana Road',
#  'Humak',
#  'Westridge',
#  'Bahria Town Rawalpindi',
#  'Gulshan Abad',
#  'Media Town',
#  'Chaklala Scheme',
#  'Chakri Road',
#  'Askari 14',
#  'Askari 13',
#  'Askari 12',
#  'Judicial Colony',
#  'Askari 10',
#  'Gulshan-e-Iqbal',
#  'Shalley Valley',
#  'Chen One Road',
#  'Adiala Road',
#  'Chandni Chowk',
#  'Askari 15',
#  'Gulistan-e-Jauhar',
#  'Malir',
#  'Gadap Town',
#  'Gulshan-e-Iqbal Town',
#  'Scheme 33',
#  'Bath Island',
#  'Abul Hassan Isphani Road',
#  'Nazimabad',
#  'Falcon Complex Faisal',
#  'Shahra-e-Faisal',
#  'Gizri',
#  'Saddar Town',
#  'Federal B Area',
#  'North Karachi',
#  'Emaar Canyon Views',
#  'D-17',
#  'G-13',
#  'F-17',
#  'I-12',
#  'F-10',
#  'F-8',
#  'Askari 7',
#  'Architects Engineers Housing Society',
#  'Samanabad',
#  'Mozang',
#  'Abdullahpur',
#  'Dhok Kashmirian',
#  'Askari 4',
#  'Askari 1',
#  'Askari 3',
#  'Askari 2',
#  'Gulraiz Housing Scheme',
#  'Navy Housing Scheme Karsaz',
#  'Jamshed Town',
#  'Bahria Town Karachi',
#  'Jinnah Avenue',
#  'PAF Housing Scheme',
#  'North Nazimabad',
#  'Kuri Road',
#  'Chatha Bakhtawar',
#  'Airport Housing Society',
#  'Sultan Pura',
#  'Sabzazar Scheme',
#  'T & T Aabpara Housing Society',
#  'Al Faisal Town',
#  'Canal Garden',
#  'Muslim Nagar Housing Scheme',
#  'Johar Town',
#  'Tricon Village',
#  'PCSIR Housing Scheme',
#  'Pak Arab Housing Society',
#  'Green Fort',
#  'Wapda Town',
#  'State Life Housing Society',
#  'Wahdat Road',
#  'DHA 11 Rahbar',
#  'Shershah Colony - Raiwind Road',
#  'Jaranwala Road',
#  'Wapda City',
#  'Lalazar',
#  'Askari 11',
#  'Satellite Town',
#  'Al-Noor Colony',
#  'Clifton',
#  'Northern Bypass',
#  'Fazaia Housing Scheme',
#  'New Karachi',
#  'Khalid Bin Walid Road',
#  'Shaheed Millat Road',
#  'Anda Mor Road',
#  'Lyari Town',
#  'I-11',
#  'National Police Foundation O-9',
#  'Korang Road',
#  'I-8',
#  'Shah Allah Ditta',
#  'G-7',
#  'Fazaia Colony',
#  'New Lalazar',
#  'Cricketer Villas',
#  'Rehman Villas',
#  'Faisal Town',
#  'Harbanspura Road',
#  'Alfalah Town',
#  'Punjab Govt Employees Society',
#  'Ashiana-e-Quaid Housing Scheme',
#  'GT Road',
#  'Affandi Colony',
#  'Sadiqabad',
#  'Defence View Society',
#  'P & T Colony',
#  'Sea View Apartments',
#  'Tariq Road',
#  'Saddar',
#  'Shalimar Housing Scheme',
#  'Garrison Homes',
#  'Khayaban-e-Amin',
#  'Shahdara',
#  'Iqbal Park',
#  'Baldia Town',
#  'Lehtarar Road',
#  'G-9',
#  'E-14',
#  'Karakoram Diplomatic Enclave',
#  'Paradise Valley',
#  'Misryal Road',
#  'Model Colony',
#  'Mustafa Town',
#  'Walton Road',
#  'New Super Town',
#  'West Wood Housing Society',
#  'Ghulam Mohammad Abad',
#  'Liaquat Bagh',
#  'Khayaban-e-Sir Syed',
#  'Zamzama',
#  'Gulshan-e-Usman Housing Society',
#  'Liaquatabad',
#  'Garden West',
#  'Palm Villas',
#  'Islampura',
#  'Mansoorah',
#  'Marghzar Officers Colony',
#  'Mughalpura',
#  'Saggian',
#  'Rasool Park',
#  'Shoukat Town',
#  'Al Hamra Town',
#  'Badami Bagh',
#  'Gulistan Colony',
#  'Lahore Motorway City',
#  'OPF Housing Scheme',
#  'Dharampura',
#  'Ferozepur Road',
#  'Township',
#  'Babu Sabu',
#  'Al Kareem Garden',
#  'Nawab Town',
#  'Gulberg Town',
#  'Chapal Uptown',
#  'I-14',
#  'Tarlai',
#  'Simly Dam Road',
#  'I-9',
#  'Burma Town',
#  'Naval Anchorage',
#  'Islamabad Highway',
#  'CBR Town',
#  'The Springs',
#  'National Police Foundation',
#  'Jhang Syedan',
#  'Arsalan Town',
#  'Kashmir Highway',
#  'Usman Town',
#  'Zulfiqar Colony',
#  'Gulbahar Scheme',
#  'Misri Shah',
#  'Punjab Small Industries Colony',
#  'Shalimar Link Road',
#  'Airline Housing Society',
#  'Airport Road',
#  'Ichhra',
#  'Kamahan Road',
#  'Mehmood Booti',
#  'Kot Lakhpat',
#  'Pakki Thatti',
#  'Canal View',
#  'Al-Hafiz Town',
#  'Pir Naseer',
#  'IBL Housing Scheme',
#  'Gulshan-e-Lahore',
#  'Qadri Colony',
#  'Audit & Accounts Housing Society',
#  'Tariq Gardens',
#  'Hameedpura',
#  'Empress Road',
#  'Khayaban-e-Jinnah Road',
#  'Ahmad Housing Society',
#  'Jallo Park Road',
#  'Green Cap Housing Society',
#  'Bismillah Housing Scheme',
#  'Fateh Garh',
#  'Raiwind Road',
#  'Jubilee Town',
#  'Park View Villas',
#  'Sant Nagar',
#  'Al Rehman Garden',
#  'Harbanspura',
#  'Qazi Town',
#  'Madina Town',
#  'Gulshan-e-Rafique',
#  'Rachna Town',
#  'Eden Valley',
#  'Ghalib City',
#  'Sargodha Road',
#  'Samundari Road',
#  'Jaranwala',
#  'Peshawar Road',
#  'Baloch Colony',
#  'Manzoor Colony',
#  'Aisha Manzil',
#  'Delhi Colony',
#  'Airport',
#  'Jamshed Road',
#  'I-10',
#  'PWD Road',
#  'Pir Sohawa',
#  'Motorway Chowk',
#  'Ali Pur',
#  'FECHS',
#  'Khanna Pul',
#  'Shaheen Town',
#  'Afshan Colony',
#  'Ghous-e-Azam Road',
#  'Girja Road',
#  'Dhoke Banaras Road',
#  'PWD Colony',
#  'Gulzar-e-Quaid Housing Society',
#  'Tulsa Road',
#  'Chibban',
#  'Ayub Colony',
#  'High Court Road',
#  'Rawat',
#  'Shams Abad',
#  'Range Road',
#  'Committee Chowk',
#  'Ashraf Garden',
#  'Al-Kabir Town',
#  'Nishat Colony',
#  'Main Canal Bank Road',
#  'College Road',
#  'Aashiana Road',
#  'Ali View Park',
#  'Divine Gardens',
#  'Rail Town (Canal City)',
#  'Bahria Nasheman',
#  'Ghaziabad',
#  'Shadbagh',
#  'Kahna',
#  'Gulshan Park',
#  'Doctors Housing Society',
#  'Taj Bagh Scheme',
#  'Vital Homes Housing Scheme',
#  'Bilal Gunj',
#  'Gohawa',
#  'Rehmanpura (Ferozpur Road)',
#  'Shadipura',
#  'Swami Nagar',
#  'Baghbanpura',
#  'Nasheman-e-Iqbal',
#  'Lake City',
#  'AWT Army Welfare Trust',
#  'Clifton Colony',
#  'Peoples Colony No 2',
#  'Hilal Road',
#  'Yousaf Town',
#  'Jail Road',
#  'Gulbahar Colony',
#  'Lasani Town',
#  'Shahzad Colony',
#  'Narwala Road',
#  '204 Chak Road',
#  'Mansoorabad',
#  'University Road',
#  'Shah Faisal Town',
#  'Civil Lines',
#  'Abid Town',
#  'Falaknaz Presidency',
#  'Bin Qasim Town',
#  'Nemat Colony No 1',
#  'Gulshan e Madina',
#  'Gulistan Colony No 1',
#  'Shalimar Park',
#  'Eden Orchard',
#  'Eden Gardens',
#  'Rail View Housing Society',
#  'Ali Town',
#  'Harley Street',
#  'Fazal Town',
#  'Chakra',
#  'Susan Road',
#  'Canal Road',
#  'Sarwar Road',
#  'G. H. Q',
#  'Eden Villas',
#  'Sui Gas Housing Society',
#  'Thokar Niaz Baig',
#  'Lahore Medical Housing Society',
#  'UBL Housing Society',
#  'Salli Town',
#  'PIA Main Boulevard',
#  'Abdalians Cooperative Housing Society',
#  'Nishtar Colony',
#  'Bhatta Chowk',
#  'Madina Colony',
#  'Highcourt Society',
#  'Ravi Park',
#  'Zaman Colony',
#  'Korangi',
#  'Hill Park',
#  'Malir Link To Super Highway',
#  'Ranchore Line Bazar',
#  'M. A. Jinnah Road',
#  'Super Highway',
#  'Jhangi Syedan',
#  'Chak Shahzad',
#  'H-13',
#  'Jaranwala Town',
#  'Khayaban Colony',
#  'Nisar Colony',
#  'Nawaban Wala',
#  'Manawala',
#  'Fareed Town',
#  'Others',
#  'Qasimabad',
#  'Palm City',
#  'Younas Town',
#  'Peoples Colony No 1',
#  'Sangar Town',
#  'KRL Road',
#  'Central Park Housing Scheme',
#  'Al-Hamad Colony (AIT)',
#  'Ameer-ud-Din Park',
#  'Ittifaq Town',
#  'Mohafiz Town',
#  'Awan Town',
#  'Shadab Garden',
#  'Al Rahim Homes',
#  'Chauburji Chowk',
#  'Islamia Park',
#  'Sunny Park',
#  'Fort Villas',
#  'PIA Housing Scheme',
#  'Shahra-e-Qaideen',
#  'Azam Town',
#  'Saima Luxury Homes',
#  'G-14',
#  'NIH Colony',
#  '7th Avenue',
#  'Shahbaz Town',
#  'Kaleem Shaheed Colony No 1',
#  'Garden Colony',
#  'Murree Road',
#  'Dhok Sayedan Road',
#  'Dhoke Khabba',
#  'Tench Road',
#  'Dream Avenue Lahore',
#  'Mehar Fayaz Colony',
#  'Al-Amin Housing Society',
#  'Defence Road',
#  'Irrigation Cooperative Housing Society',
#  'Hassan Town',
#  'Lalazaar Garden',
#  'Eden Place Housing Scheme',
#  'Sukh Chayn Gardens',
#  'BOR - Board of Revenue Housing Society',
#  'Afzal Park',
#  'Shadman 2',
#  'Naz Town',
#  'Rabia City',
#  'Mehmoodabad',
#  'Margalla Town',
#  'Tarnol',
#  'H-15',
#  'D-13',
#  'Alipur Farash',
#  'Ali Garden',
#  'Dhok Paracha',
#  'DAV College Road',
#  'Ahmad Abad',
#  'Askari 8',
#  'Green Town',
#  'Lawrence Road',
#  'Jewa Town',
#  'Raj Garh',
#  'Ahbab Colony',
#  'Shahkam Chowk',
#  'Kakezai Housing Society',
#  'Walled City',
#  'Toheed Park',
#  'Asif Colony',
#  'Outfall Road',
#  'Bagarian',
#  'Hub River Road',
#  'Suparco Road',
#  'Rufi Rose Petals',
#  'Punjab Chowrangi',
#  'Meherban Colony',
#  'Zaraj Housing Scheme',
#  'Multi Residencia & Orchards',
#  'Capital Enclave',
#  'G-16',
#  'Spring Valley',
#  'Kareem City',
#  'Lasani Garden',
#  'Gulshan-e-Hayat',
#  'Zia Colony',
#  'Sheikh Colony',
#  'Gawal Mandi',
#  'Asghar Mall Road',
#  'Air Avenue City',
#  'Saidpur Road',
#  'Friends Colony',
#  'Bilal Colony',
#  'Jinnah Colony',
#  'Sajid Garden',
#  'Salamatpura',
#  'Garhi Shahu',
#  'Sham Nagar',
#  'River View Coop Housing Society',
#  'Wahdat Colony',
#  'Bahar Shah Road',
#  'Band Road',
#  'Ring Road',
#  'Iqbal Avenue',
#  'Rehan Garden',
#  'Khaliq-uz-Zaman Road',
#  'Lyari Expressway',
#  'Orangi Town',
#  'Gulshan-e-Areesha',
#  'Javed Bahria Coopretive Housing Society',
#  'AGHOSH',
#  'Taramrri',
#  'E-16',
#  'Islamabad - Murree Expressway',
#  '9th Avenue',
#  'Jameel Town',
#  'Khayaban Colony 2',
#  'Gulfishan Colony',
#  'Dhudi Wala',
#  'Canal Park',
#  'Mahmoodabad',
#  'Shadman Colony',
#  'Bostan Road',
#  'Morgah',
#  'Lalkurti',
#  'Mohammadi Colony',
#  'Tench Bhata',
#  'Amin Town',
#  'CBR Town Phase 2',
#  'Askari 9',
#  'Abid Market',
#  'Shalimar Town',
#  'Al Hafeez Gardens',
#  'Canal Bank Housing Scheme',
#  'Tajpura',
#  'Landhi',
#  'Kashmir Road',
#  'ASF Tower',
#  'Dastgir Colony',
#  'Rashid Minhas Road',
#  'Khayaban-e-Ittehad Road',
#  'Dalmia Cement Factory Road',
#  'Defence Garden',
#  'PAEC Employees Cooperative Housing Society',
#  'D-12',
#  'Green Avenue',
#  'Koral Chowk',
#  'Jhang Road',
#  'Citi Housing Society',
#  'Bahria Orchard',
#  'Shershah Colony - Ichra',
#  'Al-Hamd Garden',
#  'Expo Avenue Society',
#  'Peco Road',
#  'Aabpara Coop Housing Society',
#  'Beacon House Society',
#  'Khayaban-e-Quaid',
#  'Manawan',
#  'Bhagatpura',
#  'PCSIR Staff Colony',
#  'P & D Housing Society',
#  'Sindh Industrial Trading Estate (SITE)',
#  'Britto Road',
#  'River Garden',
#  'E-18',
#  'Chak 208 Road',
#  'Khayaban-e-Tanveer',
#  'Dhamyal Road',
#  'Sadiqa Abad',
#  'Samarzar Housing Society',
#  'Quaid-e-Azam Colony',
#  'Sher Zaman Colony',
#  'Abdullah City',
#  'Four Season Housing',
#  'National Town',
#  'Canal Burg',
#  'Azam Gardens',
#  'Daroghewala',
#  'Eden Park',
#  'Chohan Road',
#  'Wassanpura',
#  'Ghous Garden',
#  'Kacha Jail Road',
#  'Sanda',
#  'Revenue Society',
#  'Shera Kot',
#  'Naya Nazimabad',
#  'KDA Scheme 1',
#  'Golra Mor',
#  'G-12',
#  'Shahpur',
#  '12th Avenue',
#  'Jhumra Road',
#  'Chakra Road',
#  'Al-Haram City - Phase 2',
#  'Caltex Road',
#  'Amer Pura',
#  'Kartar Pura',
#  'Peer Meher Ali Shah Town',
#  'Al Noor Garden',
#  'Millat Road',
#  'Police Foundation Housing Scheme',
#  'New Shah Kamal Colony',
#  'Birdwood Road',
#  'Dogech',
#  'Shamkay Bhattian',
#  'Rehman Gardens',
#  'Saadi Road',
#  'Karachi Motorway',
#  'Tipu Sultan Road',
#  'Club Road',
#  'Gulshan-e-Khudadad',
#  'H-12',
#  'Kacha Ferozepur Road',
#  'Sultan Town',
#  'New Chauburji Park',
#  'Ryaz ul Jannah',
#  'Suhail Abad',
#  'Safari View Residencia',
#  'Liaquat Colony',
#  'Army Officers Colony',
#  'Race Course',
#  'Kurri Road',
#  'Faisal Colony',
#  'Sheikhupura Road',
#  'Punjab Govt Servant Society',
#  'Gulshan-e-Amin',
#  'Manghopir Road',
#  'Golimar',
#  'Shah Rasool Colony',
#  'H-9',
#  'Zaheer Villas',
#  'Bhogiwal Road',
#  'Omega Homes',
#  'Al Jalil Garden',
#  'Gajju Matah',
#  'Rizwan Garden Scheme',
#  'D Type Colony',
#  'Gulgasht Colony',
#  'Guru Nanak Pura',
#  'Aria Mohalla',
#  'Kahuta',
#  'Pindora',
#  'Allama Iqbal Colony',
#  'Aslam Shaheed Road',
#  'Riaz Qureshi Road',
#  'Begampura',
#  'Rana Town',
#  'Mohlanwal',
#  'Nishtar Road (Lawrence Road)',
#  'Al-Hilal Society',
#  'Shah Jamal',
#  'Gul Kali',
#  'Eden Avenue Extension',
#  'Habib Homes',
#  'Lahore Canal Bank Cooperative Housing Society',
#  'Riwaz Garden',
#  'Manga Mandi',
#  'Azeem Garden Shahdara',
#  'Formanites Housing Scheme',
#  'Gatwala Chowk',
#  'Valencia Gardens',
#  'Allahabad Road',
#  'Cricket Stadium Road',
#  'Khayaban Gardens',
#  'Dhok Gujran',
#  'Bostan Valley',
#  'National Highway',
#  'Maqboolabad Society',
#  'Faisal Town - F-18',
#  'Al Huda Town',
#  'I-13',
#  'New Muslim Town',
#  'Sally Town South',
#  'Al-Kareem Premier Housing Scheme',
#  'Ittehad Colony',
#  'Zaitoon - New Lahore City',
#  'Jaffar Town',
#  'Bakar Mandi Road',
#  'Nazimabad Villas',
#  'Nighabanpura',
#  'Ravi Gardens',
#  'Sarafa Bazar',
#  'Khurram Colony',
#  'Frere Town',
#  'G-6',
#  'Qutbal Town',
#  'Chur Chowk',
#  'Punjab Coop Housing Society',
#  'Anarkali',
#  'Sodiwal',
#  'Shiraz Villas',
#  'NFC 1',
#  'Shah Faisal Road',
#  'Government Employees Cooperative Housing Society (GECHS)',
#  'Green View Colony',
#  'Latif Garden',
#  'Faisal Gardens',
#  'Dhanola',
#  'Islamabad Farm Houses',
#  'Banaras Colony',
#  'Chaklala',
#  'Wazir Town',
#  'Dhoke Munshi Khan',
#  'Falaknaz Dynasty',
#  'Etawa Society',
#  'C-18',
#  'Royal City',
#  'D Ground',
#  'Firdosi Road',
#  'Azizabad',
#  'Dubai Town',
#  'Farooq Colony',
#  'Ali Alam Garden',
#  'Al-Falah Cooperative Housing Society',
#  'Nussah Town',
#  'Cosmopolitan Society',
#  'Liaquat Avenue',
#  'F-9',
#  'Airport Enclave',
#  'Holy Family Road',
#  'Shah Khalid Colony',
#  'Allama Iqbal Intl Airport',
#  'TECH Society',
#  'Lahore Press Club Housing Scheme',
#  'Peer Colony',
#  'Jora Pull',
#  'Krishan Nagar',
#  'Youhanabad',
#  'Khurianwala',
#  'Shadab Colony',
#  'Dhoke Gangal',
#  'Dhoke Hassu',
#  'MT Khan Road',
#  'Dr Daud Pota Road',
#  'Shehzad Town',
#  'Raheem Gardens',
#  'Royal Garden',
#  'Super Town',
#  'Bait-ul-Raza Colony',
#  'Hamza Town',
#  'Real Cottages',
#  'Sue-e-Asal',
#  'New Garden Town',
#  'Rehmania Town',
#  'Wah Link Road',
#  'DHA City Karachi',
#  'Rawal Enclave',
#  'IJP Road',
#  'Commercial Market',
#  'Gulshan-e-Saeed',
#  'Chenab Gardens',
#  'Shakrial',
#  'Makkah Colony',
#  'Pak Park',
#  'Nabi Pura',
#  'Al Hamad Colony',
#  'Punjab University Employees Society',
#  'Surti Muslim Co-Operative Housing Society',
#  'ASF Housing Scheme',
#  'Muslimabad Society',
#  'Bilal Town',
#  'Cotton Export Cooperative Housing Society',
#  'Naval Housing Scheme',
#  'Maskan Chowrangi',
#  'Iqbal Town',
#  'Haji Abad',
#  'Sir Syed Town',
#  'Umer Garden',
#  'Kalma Chowk',
#  'Gulshan Dadan',
#  'Ahmad Avenue',
#  'Sufiabad',
#  'Al Noor Town',
#  'Gosha-e-Ahbab',
#  'Lahore Cantt Coop Housing',
#  'Walton Railway Officers Colony',
#  'Gawalmandi',
#  'Khuda Ki Basti',
#  'Shaheed-e-Millat Expressway',
#  'Hawks Bay Scheme 42',
#  'Gulistan Colony No 2',
#  'Quaid-e-Azam Park',
#  'Khanna Road',
#  'Zeeshan Colony',
#  'Tipu Road',
#  'Kacheri Chowk',
#  'Faiz Bagh',
#  'Al Jannat Housing Scheme',
#  'Jaffaria Colony',
#  'Ameen Park',
#  'Lahore Garden Housing Scheme',
#  'Rawal Town',
#  'Tariqabad',
#  'Badar Colony',
#  'PIA Colony',
#  'Jallo',
#  'Wafaqi Colony',
#  'Abdali Road',
#  'Kamran Chowrangi',
#  'Gizri Road',
#  'Peoples Colony',
#  'Daniyal Town',
#  'Gobind Pura',
#  'Transformer Chowk',
#  'Ranial',
#  'LDA Avenue',
#  'Saggian Wala Bypass Road',
#  'Gul-e-Damin',
#  'PASSCO Housing Society',
#  'Shama Road',
#  'Sheraz Town',
#  'Abdullah Haroon Road',
#  'Kashmir Colony',
#  'Steam Power Station Colony',
#  'Chanman Abad',
#  'Magistrate Colony',
#  'Sher Shah Road',
#  'Rustam Park',
#  'Mohlanwal Road',
#  'Korangi Road',
#  'Swan Garden',
#  'Karim Town',
#  'Sitara Colony',
#  'Gulshan-e-Shamal',
#  'Maulana Shaukat Ali Road',
#  'Zubaida Park',
#  'Temple Road',
#  'McLeod Road',
#  'Frash Town',
#  'Tali Mori',
#  'Al-Hamd Park',
#  'Labor Colony',
#  'Malik Park',
#  'Rehman City - Phase 4',
#  'Nai Abadi Harbanspura',
#  'Education Town',
#  'Khokhar Town',
#  'Sarwar Town',
#  'Thalian',
#  'Thanda Pani',
#  'PAF Tarnol',
#  'Raja Colony',
#  'Officers Colony',
#  'Dhoke Syedan',
#  'Chaudhary Wilayat Khan Road',
#  'People Colony',
#  'Munawar Colony',
#  'Kotli Abdur Rahman',
#  'Grand Avenues Housing Scheme',
#  'Chaudhary Park',
#  'Zero Point',
#  'Madan Pura',
#  'Lahore - Sheikhupura - Faisalabad Road',
#  'Walait Homes',
#  'Eastridge Housing Scheme',
#  'Kharak',
#  'Canal Fort II',
#  'AR Cottages',
#  'Fateh Villas',
#  'Combo Colony',
#  'Hakim Town',
#  'New Shakrial',
#  'Sihala',
#  'Rajgarh Road',
#  'Lower Mall',
#  'Jia Baga Road',
#  'Habibullah Road',
#  'Riaz ul Jannah',
#  'Nishatabad',
#  'Chah Sultan',
#  'Mangral Town',
#  'Amarpura',
#  'Saeed Colony',
#  'Azeem Town',
#  'Hanif Park Harbanspura',
#  'Sanda Road',
#  'Mustafa Abad',
#  'Scheme 45',
#  'F-15',
#  'Green Hills Housing Scheme',
#  'Hassan Villas',
#  'Babar Colony',
#  'Siddiqia Colony',
#  'China Scheme',
#  'Amir Khusro',
#  'Bankers Co-operative Housing Society',
#  'Waris Colony',
#  'Bahar Colony',
#  'Ali Housing Colony',
#  'Khawaja Islam Road',
#  'Ahmadabad',
#  'Jhang Bazar',
#  'Dheri Hassanabad',
#  'Sami Town',
#  'UET Housing Society',
#  'Alia Town',
#  'Waris Road',
#  'Dholanwal',
#  'Sakhi Hassan Chowrangi',
#  'Naval Colony',
#  'PECHS',
#  'Chauburji Park Road',
#  'Asim Town',
#  'Nemat Colony No 2',
#  'Kaleem Shaheed Colony No 2',
#  'Liaquat Town',
#  'Babuwala',
#  'New Afzal Town',
#  'Chinar Bagh',
#  'Judicial Town',
#  'G-5',
#  'Islam Nagar',
#  'Abdul Sattar Edhi Road',
#  'Heaven Homes',
#  'Kot Khawaja Saeed',
#  'Kachupura',
#  'Hajvery Housing Scheme',
#  'Makki Complex',
#  'Makkah Garden',
#  'Al Najaf Colony',
#  'Bakra Mandi',
#  'Jumma Market',
#  'Manga - Raiwind Road',
#  'Millat Colony',
#  'Kemari Town',
#  'BMCHS',
#  'Punjab Colony',
#  'Kahna Kacha',
#  'Cantt View Society',
#  'Mohni Road',
#  'Kareem Garden',
#  'Lines Area',
#  'Lalukhet',
#  'Park Road',
#  'Excise & Taxation Housing Scheme',
#  'Ismail Green Valley',
#  'Canal Expressway',
#  'Janjua Town',
#  'Cutchi Memon Cooperative Housing Society',
#  'Abdullah Ahmed Road',
#  'Nisbat Road',
#  'Al Fajar Society',
#  'Shah Di Khoi',
#  'Rajpoot Town',
#  'Shahpur Kanjra',
#  'Hanjarwal',
#  'Shah Kamal Road',
#  'Chah Miran',
#  'Partab Nagar',
#  'Johar Colony',
#  'Waris Pura',
#  'Dhandharan Chak 66 JB',
#  'Air Force Housing Society',
#  'Pir Wadhai',
#  'Agha Shahi Avenue',
#  'Singhpura',
#  'Allama Iqbal Road',
#  'Rifle Range Road',
#  'Sherwani Town Housing Scheme',
#  'Neela Gumbad',
#  'Elite Town',
#  'Green City',
#  'Defence Colony',
#  'Shah Town',
#  'Pakistan Chowk',
#  'Rufi Lake Drive Apartments',
#  'Sarai Kharbuza',
#  'Japan Road',
#  'Saidpur',
#  'Azadi Chowk',
#  'Punjab Govt. Servants Housing Foundation',
#  'Khalid Abad',
#  'Dhok Naju',
#  'Gobal Town',
#  'Dhok Hukamdad',
#  'Kamala Abad',
#  'Canalberg Housing Society',
#  'Guru Mandir Chorangi',
#  'Kuri',
#  'Marwa Town',
#  'Kehkishan Colony No 1',
#  'Ismail Valley',
#  'Rawal Road',
#  'Railway Road',
#  'Lytton Road',
#  'Lahore - Jaranwala Road',
#  'Nasirabad',
#  'D-14',
#  'Orchard Scheme',
#  'Mumtaz City',
#  'Imran Road',
#  'Chakri',
#  'Bangash Colony',
#  'Dhok Mangtal',
#  'Mohallah Raja Sultan',
#  'Nadeem Town',
#  'Shanghai Road',
#  'Zaitoon Colony',
#  'Nazir Garden Society',
#  'Mian Colony',
#  'TIP Housing Society',
#  'Teacher Society',
#  'Amil Colony',
#  'Lawyers Society',
#  'D-18',
#  'E-12',
#  'Taj Colony',
#  'Afghanabad',
#  'Rabbani Colony',
#  'Nawaz Colony',
#  'Dhok Kala Khan',
#  'Sahafi Colony',
#  'Royal Residencia',
#  'Shadman 1',
#  'Khaira',
#  'Gulshan Colony',
#  'Mohammad Nagar',
#  'Saifabad',
#  ...]

# %%
data2['city'].unique()
# Out:
# array(['Islamabad', 'Lahore', 'Faisalabad', 'Rawalpindi', 'Karachi'],
#       dtype=object)

# %%
data2['purpose'].unique()
# Out:
# array(['For Sale', 'For Rent'], dtype=object)

# %%
data3=data2.copy()

# %%
plt.rcParams['figure.figsize']=[7.50,3.50]
plt.rcParams['figure.autolayout']=True

ax=data3[['price','baths','bedrooms','Area_in_Marla']].plot(kind='box',title='boxplot')
plt.show()

# %%
sns.displot(x=data3['price'],kde=False)

# %%
min_thresold=data3['price'].quantile(0.01)
max_thresold=data3['price'].quantile(0.90)

min_thresold,max_thresold
# Out:
# (15000.0, 45000000.0)

# %%
data4=data3[(data3['price']>min_thresold)&(data3['price']<max_thresold)]

# %%
sns.distplot(x=data4['price'],kde=False)
# Out:
# <ipython-input-47-2f4b2f0d7d77>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data4['price'],kde=False)
# <Axes: >

# %%
sns.distplot(x=data4['baths'],kde=False)
# Out:
# <ipython-input-48-e66e9cc75e25>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data4['baths'],kde=False)
# <Axes: >

# %%
min_thresold=data4['baths'].quantile(0.01)
max_thresold=data4['baths'].quantile(0.99)
min_thresold,max_thresold
# Out:
# (0.0, 8.0)

# %%
data5=data4[(data4['baths']>min_thresold)&(data4['baths']<max_thresold)]

# %%
sns.distplot(x=data5['baths'],kde=False)
# Out:
# <ipython-input-52-c5787217527d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data5['baths'],kde=False)
# <Axes: >

# %%
sns.distplot(data5['bedrooms'],kde=False)
# Out:
# <ipython-input-53-ed063ae78b6c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data5['bedrooms'],kde=False)
# <Axes: xlabel='bedrooms'>

# %%
max_thresold=data5['baths'].quantile(0.99)
max_thresold

# %%
data6=data5[(data5['bedrooms']<max_thresold)]

# %%
sns.distplot(x=data6['Area_in_Marla'],kde=False)
# Out:
# <ipython-input-55-a9d2f4f015d1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data6['Area_in_Marla'],kde=False)
# <Axes: >

# %%
max_thresold=data6['Area_in_Marla'].quantile(0.999)
max_thresold
# Out:
# 140.0

# %%
data6[data6['Area_in_Marla']>max_thresold]
# Out:
#         property_type     price        location        city  baths   purpose  \
# 4923       Farm House    650000    Chak Shahzad   Islamabad      4  For Rent
# 10511      Farm House    650000    Chak Shahzad   Islamabad      4  For Rent
# 12160      Farm House  40000000           Cantt      Lahore      2  For Sale
# 13306      Farm House    850000  Orchard Scheme   Islamabad      5  For Rent
# 14863            Room     18000             G-9   Islamabad      1  For Rent
# ...               ...       ...             ...         ...    ...       ...
# 114527     Farm House     20000  Bin Qasim Town     Karachi      4  For Rent
# 120062          House  38000000            E-11   Islamabad      7  For Sale
# 121234          House   5000000    Gulshan Abad  Rawalpindi      2  For Sale
# 121262     Farm House     25000           Cantt      Lahore      1  For Sale
# 121625  Lower Portion    100000             I-8   Islamabad      5  For Rent
#
#         bedrooms  Area_in_Marla
# 4923           4          400.0
# 10511          4          400.0
# 12160          3          160.0
# 13306          5          400.0
# 14863          1          280.0
# ...          ...            ...
# 114527         2          400.0
# 120062         6          200.0
# 121234         2         1234.0
# 121262         1          180.0
# 121625         4          240.0
#
# [77 rows x 8 columns]

# %%
data7=data6[(data6['Area_in_Marla']<max_thresold)]

# %%
sns.distplot(x=data7['Area_in_Marla'],kde=False)
# Out:
# <ipython-input-59-722035bcf69d>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data7['Area_in_Marla'],kde=False)
# <Axes: >

# %%
data7.to_csv('cleaned_data_for_model.csv')
