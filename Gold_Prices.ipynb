# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshad-Aziz/technical-training/blob/main/Gold_Prices.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('gold-prices.csv',index_col='Date',parse_dates=True)
df
# Out:
#               Price
# Date
# 1988-05-01   451.32
# 1988-06-01   451.66
# 1988-07-01   437.45
# 1988-10-01   406.39
# 1988-11-01   419.97
# ...             ...
# 2019-02-01  1319.76
# 2019-03-01  1302.29
# 2019-07-01  1414.61
# 2019-08-01  1497.10
# 2019-11-01  1471.92
#
# [384 rows x 1 columns]

# %%
df.tail()
# Out:
#               Price
# Date
# 2019-02-01  1319.76
# 2019-03-01  1302.29
# 2019-07-01  1414.61
# 2019-08-01  1497.10
# 2019-11-01  1471.92

# %%
plt.figure(figsize=(16,7))
#sns.lineplpot(data=df)
x=plt.xticks(rotation=90)
sns.lineplot(data=df['Price'],color='r')
plt.grid(True)

# %%
plt.figure(figsize=(16,7))
sns.histplot(df['Price'],color='r')
plt.grid(True)

# %%
plt.figure(figsize=(16,7))
sns.kdeplot(df['Price'],fill=True,color='r')
plt.grid(True)
