# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshad-Aziz/technical-training/blob/main/Mobile_Price_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
import datetime
import re

# %%
df=pd.read_csv('mobile_prices_2023.csv')
df.head()
# Out:
#                       Phone Name  Rating ?/5 Number of Ratings       RAM  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2            33,561  2 GB RAM
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2            77,128  4 GB RAM
# 2   POCO C51 (Royal Blue, 64 GB)         4.3            15,175  4 GB RAM
# 3    POCO C55 (Cool Blue, 64 GB)         4.2            22,621  4 GB RAM
# 4  POCO C51 (Power Black, 64 GB)         4.3            15,175  4 GB RAM
#
#   ROM/Storage       Back/Rare Camera      Front Camera   Battery  \
# 0   32 GB ROM        8MP Dual Camera  5MP Front Camera  5000 mAh
# 1   64 GB ROM             50MP + 2MP  8MP Front Camera  5000 mAh
# 2   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 3   64 GB ROM  50MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 4   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
#
#                                            Processor Price in INR  \
# 0  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...       ₹5,649
# 1                   Mediatek Dimensity 700 Processor      ₹11,999
# 2                                Helio G36 Processor       ₹6,999
# 3                       Mediatek Helio G85 Processor       ₹7,749
# 4                                Helio G36 Processor       ₹6,999
#
#   Date of Scraping
# 0       2023-06-17
# 1       2023-06-17
# 2       2023-06-17
# 3       2023-06-17
# 4       2023-06-17

# %%
df.isnull().sum()
# Out:
# Phone Name             0
# Rating ?/5             0
# Number of Ratings      0
# RAM                    0
# ROM/Storage          174
# Back/Rare Camera       9
# Front Camera         401
# Battery               10
# Processor             55
# Price in INR           0
# Date of Scraping       0
# dtype: int64

# %%
df.sample(10)
# Out:
#                                  Phone Name  Rating ?/5 Number of Ratings  \
# 968   vivo V27 Pro 5G (Noble Black, 128 GB)         4.4             5,070
# 593      SAMSUNG Galaxy A04s (Green, 64 GB)         4.1                74
# 1067       vivo T1 5G (Silky White, 128 GB)         4.4          1,75,223
# 1423                Nokia C31 (CYAN, 64 GB)         3.9                34
# 1783  Infinix Hot 11 (Emerald Green, 64 GB)         4.3            16,419
# 216        realme C25s (Watery Blue, 64 GB)         4.4            51,873
# 1410               Nokia 2.2 (Steel, 16 GB)         4.0             3,190
# 1235       Redmi K20 (Glacier Blue, 128 GB)         4.5            51,408
# 920        vivo V27 5G (Magic Blue, 256 GB)         4.4             1,897
# 667      SAMSUNG Galaxy A12 (White, 128 GB)         4.1             1,353
#
#             RAM ROM/Storage         Back/Rare Camera       Front Camera  \
# 968    8 GB RAM  128 GB ROM   50MP (OIS) + 8MP + 2MP  50MP Front Camera
# 593    4 GB RAM   64 GB ROM  50MP + 50MP + 2MP + 2MP   5MP Front Camera
# 1067   6 GB RAM  128 GB ROM         50MP + 2MP + 2MP  16MP Front Camera
# 1423   4 GB RAM   64 GB ROM         13MP Rear Camera                NaN
# 1783   4 GB RAM   64 GB ROM        13MP + Depth Lens   8MP Front Camera
# 216    4 GB RAM   64 GB ROM         13MP + 2MP + 2MP   8MP Front Camera
# 1410   2 GB RAM   16 GB ROM         13MP Rear Camera   5MP Front Camera
# 1235   6 GB RAM  128 GB ROM        48MP + 13MP + 8MP  20MP Front Camera
# 920   12 GB RAM  256 GB ROM   50MP (OIS) + 8MP + 2MP  50MP Front Camera
# 667    6 GB RAM  128 GB ROM   48MP + 5MP + 2MP + 2MP   8MP Front Camera
#
#        Battery                              Processor Price in INR  \
# 968   4600 mAh      Mediatek Dimensity 8200 Processor      ₹37,999
# 593   5000 mAh   Exynos Octa Core Processor Processor      ₹12,499
# 1067  5000 mAh      Qualcomm Snapdragon 695 Processor      ₹16,990
# 1423  5050 mAh  1 year domestic replacement guarantee       ₹9,999
# 1783  5200 mAh           MediaTek Helio G70 Processor       ₹9,999
# 216   6000 mAh           MediaTek Helio G85 Processor       ₹8,999
# 1410  3000 mAh           MediaTek Helio A22 Processor       ₹8,599
# 1235  4000 mAh      Qualcomm Snapdragon 730 Processor      ₹24,999
# 920   4600 mAh   Mediatek Dimensity 7200 5G Processor      ₹36,999
# 667   5000 mAh         Exynos 850 (S5E3830) Processor      ₹17,999
#
#      Date of Scraping
# 968        2023-06-17
# 593        2023-06-17
# 1067       2023-06-17
# 1423       2023-06-17
# 1783       2023-06-17
# 216        2023-06-17
# 1410       2023-06-17
# 1235       2023-06-17
# 920        2023-06-17
# 667        2023-06-17

# %%
df['Company Name']=df['Phone Name'].str.split(" ").str[0]

# %%
df['Company Name'].unique()
# Out:
# array(['POCO', 'realme', 'Realme', 'APPLE', 'Apple', 'SAMSUNG', 'OPPO',
#        'Google', 'vivo', 'Nothing', 'REDMI', 'Redmi', 'Mi', 'Xiaomi',
#        '10A', '�9A', 'Nokia', 'MOTOROLA', 'A10E', 'Motorola', 'a', 'Moto',
#        'OnePlus', 'Huawei', 'Nexus', 'Alcatel', 'Lenovo', 'Infinix'],
#       dtype=object)

# %%
df['Company Name']=df['Company Name'].str.replace('Realme','realme')
df['Company Name']=df['Company Name'].str.replace('Apple','APPLE')
df['Company Name']=df['Company Name'].str.replace('Redmi','REDMI')
df['Company Name']=df['Company Name'].str.replace('Xiaomi','Mi')
df['Company Name']=df['Company Name'].str.replace('Motorola','MOTOROLA')
df['Company Name']=df['Company Name'].str.replace('Moto','MOTOROLA')

# %%
df['Company Name'].unique()
# Out:
# array(['POCO', 'realme', 'APPLE', 'SAMSUNG', 'OPPO', 'Google', 'vivo',
#        'Nothing', 'REDMI', 'Mi', '10A', '�9A', 'Nokia', 'MOTOROLA',
#        'A10E', 'a', 'OnePlus', 'Huawei', 'Nexus', 'Alcatel', 'Lenovo',
#        'Infinix'], dtype=object)

# %%
df=df[(df['Company Name']!='10A')&(df['Company Name']!='a')& (df['Company Name']!='�9A')&(df['Company Name']!='A10E')]

# %%
df['Company Name'].unique()
# Out:
# array(['POCO', 'realme', 'APPLE', 'SAMSUNG', 'OPPO', 'Google', 'vivo',
#        'Nothing', 'REDMI', 'Mi', 'Nokia', 'MOTOROLA', 'OnePlus', 'Huawei',
#        'Nexus', 'Alcatel', 'Lenovo', 'Infinix'], dtype=object)

# %%
df.sample(5)
# Out:
#                                              Phone Name  Rating ?/5  \
# 1392                                        Nokia C2-00         0.0
# 457   Apple iPhone XR (Blue, 256 GB) (Includes EarPo...         4.6
# 458   Apple iPhone XR (Coral, 64 GB) (Includes EarPo...         4.6
# 80            POCO M2 Pro (Two Shades of Black, 128 GB)         4.4
# 799            OPPO Find N2 Flip (Astral Black, 256 GB)         4.3
#
#      Number of Ratings         RAM ROM/Storage        Back/Rare Camera  \
# 1392                 0  cm Display         NaN                     NaN
# 457           1,00,858  256 GB ROM         NaN        12MP Rear Camera
# 458           1,00,858   64 GB ROM         NaN        12MP Rear Camera
# 80            3,52,150    6 GB RAM  128 GB ROM  48MP + 8MP + 5MP + 2MP
# 799                210    8 GB RAM  256 GB ROM              50MP + 8MP
#
#            Front Camera   Battery                           Processor  \
# 1392                NaN       NaN                                 NaN
# 457    7MP Front Camera   A12 mAh            Brand Warranty of 1 Year
# 458    7MP Front Camera   A12 mAh                   iOS 13 Compatible
# 80    16MP Front Camera  5000 mAh  Qualcomm Snapdragon 720G Processor
# 799   32MP Front Camera  4300 mAh  Mediatek Dimensity 9000+ Processor
#
#      Price in INR Date of Scraping Company Name
# 1392       ₹2,967       2023-06-17        Nokia
# 457       ₹91,900       2023-06-17        APPLE
# 458       ₹36,999       2023-06-17        APPLE
# 80        ₹19,999       2023-06-17         POCO
# 799       ₹89,999       2023-06-17         OPPO

# %%
df1=df.copy()

# %%
df1['Number of Ratings']=df1['Number of Ratings'].replace({',':''},regex=True)
df1.head(5)
# Out:
#                       Phone Name  Rating ?/5 Number of Ratings       RAM  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2             33561  2 GB RAM
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2             77128  4 GB RAM
# 2   POCO C51 (Royal Blue, 64 GB)         4.3             15175  4 GB RAM
# 3    POCO C55 (Cool Blue, 64 GB)         4.2             22621  4 GB RAM
# 4  POCO C51 (Power Black, 64 GB)         4.3             15175  4 GB RAM
#
#   ROM/Storage       Back/Rare Camera      Front Camera   Battery  \
# 0   32 GB ROM        8MP Dual Camera  5MP Front Camera  5000 mAh
# 1   64 GB ROM             50MP + 2MP  8MP Front Camera  5000 mAh
# 2   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 3   64 GB ROM  50MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 4   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
#
#                                            Processor Price in INR  \
# 0  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...       ₹5,649
# 1                   Mediatek Dimensity 700 Processor      ₹11,999
# 2                                Helio G36 Processor       ₹6,999
# 3                       Mediatek Helio G85 Processor       ₹7,749
# 4                                Helio G36 Processor       ₹6,999
#
#   Date of Scraping Company Name
# 0       2023-06-17         POCO
# 1       2023-06-17         POCO
# 2       2023-06-17         POCO
# 3       2023-06-17         POCO
# 4       2023-06-17         POCO

# %%
df1['Number of Ratings']=df1['Number of Ratings'].astype(int)
df1['Number of Ratings'].dtype
# Out:
# dtype('int64')

# %%
df1['Ram_size']=df1['RAM'].str.split(' ').str[0]
df.head(1)
# Out:
#                      Phone Name  Rating ?/5 Number of Ratings       RAM  \
# 0  POCO C50 (Royal Blue, 32 GB)         4.2            33,561  2 GB RAM
#
#   ROM/Storage Back/Rare Camera      Front Camera   Battery  \
# 0   32 GB ROM  8MP Dual Camera  5MP Front Camera  5000 mAh
#
#                                            Processor Price in INR  \
# 0  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...       ₹5,649
#
#   Date of Scraping Company Name
# 0       2023-06-17         POCO

# %%
df1['Ram_size'].unique()
# Out:
# array(['2', '4', '6', '3', '8', '12', '128', '64', '256', '512', '16',
#        '32', '1', 'NA', 'Expandable', '0', '0.53', '153', '3.81', 'cm',
#        '48', '0.046875', '768', '1.5', '60', '80', '50'], dtype=object)

# %%
df1=df1[(df1['Ram_size']!='NA')&(df1['Ram_size']!='Expandable')&(df1['Ram_size']!='cm')&(df1['Ram_size']!='768')]

# %%
df1['Ram_size'].unique()
# Out:
# array(['2', '4', '6', '3', '8', '12', '128', '64', '256', '512', '16',
#        '32', '1', '0', '0.53', '153', '3.81', '48', '0.046875', '1.5',
#        '60', '80', '50'], dtype=object)

# %%
df2=df1.copy()

# %%
df2['Storage_size']=df2['ROM/Storage'].str.split(' ').str[0]

# %%
df2['Storage_size'].isnull().sum()
# Out:
# 150

# %%
df2['Battery_size']=df2['Battery'].str.split(" ").str[0]
df2['Battery_size'].unique()
# Out:
# array(['5000', '4500', '4000', '5160', '6000', '5065', '4200', '4300',
#        '4230', 'A15', 'A13', 'A14', 'A16', 'A12', 'A9', 'Apple', '1',
#        '800', '3300', '3900', '0', '7000', '3700', '4700', '3000', '1500',
#        '1000', nan, '2000', '2600', '2050', '4800', '4015', '4025',
#        '3400', '3765', '4350', '4310', '3200', '4020', '4410', '4270',
#        '4926', '2915', '4600', '4030', '4050', '4810', '4830', '4870',
#        '4450', '3315', '3225', '3260', '4250', '4520', '3080', '3120',
#        '5018', '4100', '5020', '4850', '3030', '3010', '4820', '4780',
#        '5300', '1020', 'MediaTek', 'Brand', '1200', '1450', '1150',
#        '5050', '3060', 'Unisoc', '4950', '12', '2150', '950', '1430',
#        '1110', '4400', '2', '4610', '4115', '3800', '4085', '2100',
#        '3340', '3450', '2300', '2200', '2610', '2580', '1400', '850',
#        '650', '1800', '2500', '3760', '3500', '5200'], dtype=object)

# %%
df2=df2[(df2['Battery_size']!='A15')&(df2['Battery_size']!='A13')&
 (df2['Battery_size']!='A14')&(df2['Battery_size']!='A16')&
 (df2['Battery_size']!='A12')&(df2['Battery_size']!='A9')&
 (df2['Battery_size']!='Apple')&(df2['Battery_size']!='1')&
 (df2['Battery_size']!='nan')&(df2['Battery_size']!='MediaTek')&
  (df2['Battery_size']!='Brand')&(df2['Battery_size']!='Unisoc')]

# %%
df2['Battery_size'].unique()
# Out:
# array(['5000', '4500', '4000', '5160', '6000', '5065', '4200', '4300',
#        '4230', '800', '3300', '3900', '0', '7000', '3700', '4700', '3000',
#        '1500', '1000', nan, '2000', '2600', '2050', '4800', '4015',
#        '4025', '3400', '3765', '4350', '4310', '3200', '4020', '4410',
#        '4270', '4926', '2915', '4600', '4030', '4050', '4810', '4830',
#        '4870', '4450', '3315', '3225', '3260', '4250', '4520', '3080',
#        '3120', '5018', '4100', '5020', '4850', '3030', '3010', '4820',
#        '4780', '5300', '1020', '1200', '1450', '1150', '5050', '3060',
#        '4950', '12', '2150', '950', '1430', '1110', '4400', '2', '4610',
#        '4115', '3800', '4085', '2100', '3340', '3450', '2300', '2200',
#        '2610', '2580', '1400', '850', '650', '1800', '2500', '3760',
#        '3500', '5200'], dtype=object)

# %%
df2['Price in INR']=df2['Price in INR'].replace({'₹':''},regex=True)
df2['Price in INR']=df2['Price in INR'].replace({',':''},regex=True)

# %%
df2.head()
# Out:
#                       Phone Name  Rating ?/5  Number of Ratings       RAM  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2              33561  2 GB RAM
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2              77128  4 GB RAM
# 2   POCO C51 (Royal Blue, 64 GB)         4.3              15175  4 GB RAM
# 3    POCO C55 (Cool Blue, 64 GB)         4.2              22621  4 GB RAM
# 4  POCO C51 (Power Black, 64 GB)         4.3              15175  4 GB RAM
#
#   ROM/Storage       Back/Rare Camera      Front Camera   Battery  \
# 0   32 GB ROM        8MP Dual Camera  5MP Front Camera  5000 mAh
# 1   64 GB ROM             50MP + 2MP  8MP Front Camera  5000 mAh
# 2   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 3   64 GB ROM  50MP Dual Rear Camera  5MP Front Camera  5000 mAh
# 4   64 GB ROM   8MP Dual Rear Camera  5MP Front Camera  5000 mAh
#
#                                            Processor Price in INR  \
# 0  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...         5649
# 1                   Mediatek Dimensity 700 Processor        11999
# 2                                Helio G36 Processor         6999
# 3                       Mediatek Helio G85 Processor         7749
# 4                                Helio G36 Processor         6999
#
#   Date of Scraping Company Name Ram_size Storage_size Battery_size
# 0       2023-06-17         POCO        2           32         5000
# 1       2023-06-17         POCO        4           64         5000
# 2       2023-06-17         POCO        4           64         5000
# 3       2023-06-17         POCO        4           64         5000
# 4       2023-06-17         POCO        4           64         5000

# %%
df3=df2.copy()

# %%
df2['Company Name'].unique()
# Out:
# array(['POCO', 'realme', 'SAMSUNG', 'OPPO', 'Google', 'vivo', 'Nothing',
#        'REDMI', 'Mi', 'Nokia', 'MOTOROLA', 'OnePlus', 'Huawei', 'Nexus',
#        'Alcatel', 'Lenovo', 'Infinix'], dtype=object)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1630 entries, 0 to 1835
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Phone Name         1630 non-null   object
#  1   Rating ?/5         1630 non-null   float64
#  2   Number of Ratings  1630 non-null   int64
#  3   RAM                1630 non-null   object
#  4   ROM/Storage        1628 non-null   object
#  5   Back/Rare Camera   1630 non-null   object
#  6   Front Camera       1290 non-null   object
#  7   Battery            1629 non-null   object
#  8   Processor          1620 non-null   object
#  9   Price in INR       1630 non-null   object
#  10  Date of Scraping   1630 non-null   object
#  11  Company Name       1630 non-null   object
#  12  Ram_size           1630 non-null   object
#  13  Storage_size       1628 non-null   object
#  14  Battery_size       1629 non-null   object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 203.8+ KB

# %%
df3['Price in INR']=df3['Price in INR'].astype(int)
df3['Ram_size']=df3['Ram_size'].astype(float)

# %%
df3['Date of Scraping']=pd.to_datetime(df3['Date of Scraping'])

# %%
df.head(1)
# Out:
#                      Phone Name  Rating ?/5 Number of Ratings       RAM  \
# 0  POCO C50 (Royal Blue, 32 GB)         4.2            33,561  2 GB RAM
#
#   ROM/Storage Back/Rare Camera      Front Camera   Battery  \
# 0   32 GB ROM  8MP Dual Camera  5MP Front Camera  5000 mAh
#
#                                            Processor Price in INR  \
# 0  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...       ₹5,649
#
#   Date of Scraping Company Name
# 0       2023-06-17         POCO

# %%
cols_list=['RAM','ROM/Storage','Battery']
df3.drop(cols_list,axis=1,inplace=True)
df3.head()
# Out:
#                       Phone Name  Rating ?/5  Number of Ratings  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2              33561
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2              77128
# 2   POCO C51 (Royal Blue, 64 GB)         4.3              15175
# 3    POCO C55 (Cool Blue, 64 GB)         4.2              22621
# 4  POCO C51 (Power Black, 64 GB)         4.3              15175
#
#         Back/Rare Camera      Front Camera  \
# 0        8MP Dual Camera  5MP Front Camera
# 1             50MP + 2MP  8MP Front Camera
# 2   8MP Dual Rear Camera  5MP Front Camera
# 3  50MP Dual Rear Camera  5MP Front Camera
# 4   8MP Dual Rear Camera  5MP Front Camera
#
#                                            Processor  Price in INR  \
# 0  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...          5649
# 1                   Mediatek Dimensity 700 Processor         11999
# 2                                Helio G36 Processor          6999
# 3                       Mediatek Helio G85 Processor          7749
# 4                                Helio G36 Processor          6999
#
#   Date of Scraping Company Name  Ram_size Storage_size Battery_size
# 0       2023-06-17         POCO       2.0           32         5000
# 1       2023-06-17         POCO       4.0           64         5000
# 2       2023-06-17         POCO       4.0           64         5000
# 3       2023-06-17         POCO       4.0           64         5000
# 4       2023-06-17         POCO       4.0           64         5000

# %%
df3.isnull().sum()
# Out:
# Phone Name             0
# Rating ?/5             0
# Number of Ratings      0
# Back/Rare Camera       0
# Front Camera         340
# Processor             10
# Price in INR           0
# Date of Scraping       0
# Company Name           0
# Ram_size               0
# Storage_size           2
# Battery_size           1
# dtype: int64

# %%
EDA_df=df3.dropna()
EDA_df
# Out:
#                                     Phone Name  Rating ?/5  Number of Ratings  \
# 0                 POCO C50 (Royal Blue, 32 GB)         4.2              33561
# 1                POCO M4 5G (Cool Blue, 64 GB)         4.2              77128
# 2                 POCO C51 (Royal Blue, 64 GB)         4.3              15175
# 3                  POCO C55 (Cool Blue, 64 GB)         4.2              22621
# 4                POCO C51 (Power Black, 64 GB)         4.3              15175
# ...                                        ...         ...                ...
# 1831      Infinix Note 7 (Forest Green, 64 GB)         4.3              25582
# 1832      Infinix Note 7 (Bolivia Blue, 64 GB)         4.3              25582
# 1833      Infinix Note 7 (Aether Black, 64 GB)         4.3              25582
# 1834  Infinix Zero 8i (Silver Diamond, 128 GB)         4.2               7117
# 1835          Infinix S5 (Quetzal Cyan, 64 GB)         4.3              15701
#
#                          Back/Rare Camera                  Front Camera  \
# 0                         8MP Dual Camera              5MP Front Camera
# 1                              50MP + 2MP              8MP Front Camera
# 2                    8MP Dual Rear Camera              5MP Front Camera
# 3                   50MP Dual Rear Camera              5MP Front Camera
# 4                    8MP Dual Rear Camera              5MP Front Camera
# ...                                   ...                           ...
# 1831    48MP + 2MP + 2MP + AI Lens Camera             16MP Front Camera
# 1832    48MP + 2MP + 2MP + AI Lens Camera             16MP Front Camera
# 1833    48MP + 2MP + 2MP + AI Lens Camera             16MP Front Camera
# 1834    48MP + 8MP + 2MP + AI Lens Camera  16MP + 8MP Dual Front Camera
# 1835  16MP + 5MP + 2MP + Low Light Sensor             32MP Front Camera
#
#                                               Processor  Price in INR  \
# 0     Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...          5649
# 1                      Mediatek Dimensity 700 Processor         11999
# 2                                   Helio G36 Processor          6999
# 3                          Mediatek Helio G85 Processor          7749
# 4                                   Helio G36 Processor          6999
# ...                                                 ...           ...
# 1831                       MediaTek Helio G70 Processor         14999
# 1832                       MediaTek Helio G70 Processor         14999
# 1833                       MediaTek Helio G70 Processor         14999
# 1834                      MediaTek Helio G90T Processor         18999
# 1835                      Helio P22 (MTK6762) Processor         10999
#
#      Date of Scraping Company Name  Ram_size Storage_size Battery_size
# 0          2023-06-17         POCO       2.0           32         5000
# 1          2023-06-17         POCO       4.0           64         5000
# 2          2023-06-17         POCO       4.0           64         5000
# 3          2023-06-17         POCO       4.0           64         5000
# 4          2023-06-17         POCO       4.0           64         5000
# ...               ...          ...       ...          ...          ...
# 1831       2023-06-17      Infinix       4.0           64         5000
# 1832       2023-06-17      Infinix       4.0           64         5000
# 1833       2023-06-17      Infinix       4.0           64         5000
# 1834       2023-06-17      Infinix       8.0          128         4500
# 1835       2023-06-17      Infinix       4.0           64         4000
#
# [1290 rows x 12 columns]

# %%
EDA_df.to_csv('Data for EDA.csv')

# %%
df3.head()
# Out:
#                       Phone Name  Rating ?/5  Number of Ratings  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2              33561
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2              77128
# 2   POCO C51 (Royal Blue, 64 GB)         4.3              15175
# 3    POCO C55 (Cool Blue, 64 GB)         4.2              22621
# 4  POCO C51 (Power Black, 64 GB)         4.3              15175
#
#         Back/Rare Camera      Front Camera  \
# 0        8MP Dual Camera  5MP Front Camera
# 1             50MP + 2MP  8MP Front Camera
# 2   8MP Dual Rear Camera  5MP Front Camera
# 3  50MP Dual Rear Camera  5MP Front Camera
# 4   8MP Dual Rear Camera  5MP Front Camera
#
#                                            Processor  Price in INR  \
# 0  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...          5649
# 1                   Mediatek Dimensity 700 Processor         11999
# 2                                Helio G36 Processor          6999
# 3                       Mediatek Helio G85 Processor          7749
# 4                                Helio G36 Processor          6999
#
#   Date of Scraping Company Name  Ram_size Storage_size Battery_size
# 0       2023-06-17         POCO       2.0           32         5000
# 1       2023-06-17         POCO       4.0           64         5000
# 2       2023-06-17         POCO       4.0           64         5000
# 3       2023-06-17         POCO       4.0           64         5000
# 4       2023-06-17         POCO       4.0           64         5000

# %%
df3.head()
# Out:
#                       Phone Name  Rating ?/5  Number of Ratings  \
# 0   POCO C50 (Royal Blue, 32 GB)         4.2              33561
# 1  POCO M4 5G (Cool Blue, 64 GB)         4.2              77128
# 2   POCO C51 (Royal Blue, 64 GB)         4.3              15175
# 3    POCO C55 (Cool Blue, 64 GB)         4.2              22621
# 4  POCO C51 (Power Black, 64 GB)         4.3              15175
#
#         Back/Rare Camera      Front Camera  \
# 0        8MP Dual Camera  5MP Front Camera
# 1             50MP + 2MP  8MP Front Camera
# 2   8MP Dual Rear Camera  5MP Front Camera
# 3  50MP Dual Rear Camera  5MP Front Camera
# 4   8MP Dual Rear Camera  5MP Front Camera
#
#                                            Processor  Price in INR  \
# 0  Mediatek Helio A22 Processor, Upto 2.0 GHz Pro...          5649
# 1                   Mediatek Dimensity 700 Processor         11999
# 2                                Helio G36 Processor          6999
# 3                       Mediatek Helio G85 Processor          7749
# 4                                Helio G36 Processor          6999
#
#   Date of Scraping Company Name  Ram_size Storage_size Battery_size
# 0       2023-06-17         POCO       2.0           32         5000
# 1       2023-06-17         POCO       4.0           64         5000
# 2       2023-06-17         POCO       4.0           64         5000
# 3       2023-06-17         POCO       4.0           64         5000
# 4       2023-06-17         POCO       4.0           64         5000

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1630 entries, 0 to 1835
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Phone Name         1630 non-null   object
#  1   Rating ?/5         1630 non-null   float64
#  2   Number of Ratings  1630 non-null   int64
#  3   Back/Rare Camera   1630 non-null   object
#  4   Front Camera       1290 non-null   object
#  5   Processor          1620 non-null   object
#  6   Price in INR       1630 non-null   int64
#  7   Date of Scraping   1630 non-null   datetime64[ns]
#  8   Company Name       1630 non-null   object
#  9   Ram_size           1630 non-null   float64
#  10  Storage_size       1628 non-null   object
#  11  Battery_size       1629 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(7)
# memory usage: 165.5+ KB

# %%
df3.drop(['Phone Name','Front Camera','Back/Rare Camera'],axis=1,inplace=True)

# %%
df3.to_csv('Dataset for SA and ML.csv')
