# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshad-Aziz/technical-training/blob/main/House_prices_Model_Building.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
df=pd.read_csv('cleaned_data_for_model.csv')
df.head(2)
# Out:
#    Unnamed: 0 property_type     price location       city  baths   purpose  \
# 0           0          Flat  10000000     G-10  Islamabad      2  For Sale
# 1           1          Flat   6900000     E-11  Islamabad      3  For Sale
#
#    bedrooms  Area_in_Marla
# 0         2            4.0
# 1         3            5.6

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)
df.head()
# Out:
#   property_type     price     location       city  baths   purpose  bedrooms  \
# 0          Flat  10000000         G-10  Islamabad      2  For Sale         2
# 1          Flat   6900000         E-11  Islamabad      3  For Sale         3
# 2         House  16500000         G-15  Islamabad      6  For Sale         5
# 3         House  43500000    Bani Gala  Islamabad      4  For Sale         4
# 4         House   7000000  DHA Defence  Islamabad      3  For Sale         3
#
#    Area_in_Marla
# 0            4.0
# 1            5.6
# 2            8.0
# 3           40.0
# 4            8.0

# %%
x=df.drop(['price'],axis=1)
y=df.iloc[:,1:2]

# %%
x
# Out:
#        property_type                location        city  baths   purpose  \
# 0               Flat                    G-10   Islamabad      2  For Sale
# 1               Flat                    E-11   Islamabad      3  For Sale
# 2              House                    G-15   Islamabad      6  For Sale
# 3              House               Bani Gala   Islamabad      4  For Sale
# 4              House             DHA Defence   Islamabad      3  For Sale
# ...              ...                     ...         ...    ...       ...
# 77128  Lower Portion                     I-8   Islamabad      3  For Rent
# 77129  Lower Portion                    G-15   Islamabad      2  For Rent
# 77130  Upper Portion                     I-8   Islamabad      3  For Rent
# 77131          House  Bahria Town Rawalpindi  Rawalpindi      4  For Sale
# 77132          House           Peshawar Road  Rawalpindi      5  For Sale
#
#        bedrooms  Area_in_Marla
# 0             2            4.0
# 1             3            5.6
# 2             5            8.0
# 3             4           40.0
# 4             3            8.0
# ...         ...            ...
# 77128         3           24.0
# 77129         2            8.0
# 77130         3           12.0
# 77131         3            5.0
# 77132         4            4.0
#
# [77133 rows x 7 columns]

# %%
y
# Out:
#           price
# 0      10000000
# 1       6900000
# 2      16500000
# 3      43500000
# 4       7000000
# ...         ...
# 77128     75000
# 77129     30000
# 77130     70000
# 77131  10500000
# 77132  10000000
#
# [77133 rows x 1 columns]

# %%
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[0,1,2,4])],remainder='passthrough')
x=ct.fit_transform(x)

# %%
x
# Out:
# <77133x1392 sparse matrix of type '<class 'numpy.float64'>'
# 	with 539683 stored elements in Compressed Sparse Row format>

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

model.fit(x_train,y_train)
prediction=model.predict(x_test)

# %%
linear_model=model.score(x_test,y_test)
print('Linear model score:',linear_model)
# Out:
# Linear model score: 0.6880563642868642

# %%
from sklearn import tree
dt_model=tree.DecisionTreeRegressor(criterion='squared_error',max_depth=3,max_leaf_nodes=5)
dt_model.fit(x_train,y_train)
dt_score=dt_model.score(x_test,y_test)
print('Decision Tree model score:',dt_score)
# Out:
# Decision Tree model score: 0.7256694503401127

# %%
from sklearn.ensemble import RandomForestRegressor
random_forest_model=RandomForestRegressor(n_estimators=10,
                                          criterion='squared_error',
                                          max_depth=5,
                                          min_samples_leaf=5,)
random_forest_model.fit(x_train,y_train)
random_forest_score=random_forest_model.score(x_test,y_test)
print('Random Forest score is:',random_forest_score)
# Out:
# <ipython-input-17-8e0a248cfa31>:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   random_forest_model.fit(x_train,y_train)
# Random Forest score is: 0.7937144898615947

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model=KNeighborsRegressor(n_neighbors=5,
                              weights='distance')
knn_model.fit(x_train,y_train)
knn_score=knn_model.score(x_test,y_test)
print('KNN score:',knn_score)
# Out:
# KNN score: 0.8863664607378898

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbm=GradientBoostingRegressor(learning_rate=1.0,
                              n_estimators=20,
                              max_depth=5,
                              min_samples_leaf=5)
gbm.fit(x_train,y_train)
gbs=gbm.score(x_test,y_test)
print('GRandient Boost Model Score:',gbs)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_gb.py:437: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GRandient Boost Model Score: 0.8757833685651163

# %%
import xgboost as xgb
xgb_model=xgb.XGBRegressor(objective='reg:linear',random_state=42)
xgb_model.fit(x_train,y_train)
xgb_score=xgb_model.score(x_test,y_test)
print('XG Boost Score:',xgb_score)
# Out:
# [13:44:59] WARNING: ../src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# XG Boost Score: 0.8970985428185709

# %%
from sklearn.ensemble import AdaBoostRegressor
adaboost_model=AdaBoostRegressor(n_estimators=20,
                                 learning_rate=0.1,
                                 loss='square')
adaboost_model.fit(x_train,y_train)
adaboost_score=adaboost_model.score(x_test,y_test)
print('ADA boost model score:',adaboost_score)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ADA boost model score: 0.747493131129551

# %%
input_data=[['House','Wazir Town','Rawalpindi',4,'For Sale',3,165.9]]
input_data1=pd.DataFrame(input_data,columns=['property_type'	,'location',	'city'	,'baths'	,'purpose'	,'bedrooms',	'Area_in_Marla'])
ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[0,1,2,4])],remainder='passthrough')
input_data2=ct.fit_transform(input_data1)

input_data2
# Out:
# array([[  1. ,   1. ,   1. ,   1. ,   4. ,   3. , 165.9]])

# %%
import pickle
pickle.dump(knn_model,open('House_price_Prediction_with_knn.pk','wb'))

# %%
pickled_model=pickle.load(open('House_price_Prediction_with_knn.pk','rb'))
pickled_model.predict(x_test)
# Out:
# array([[14900000.],
#        [ 5900000.],
#        [20200000.],
#        ...,
#        [32700000.],
#        [33400000.],
#        [ 9600000.]])
